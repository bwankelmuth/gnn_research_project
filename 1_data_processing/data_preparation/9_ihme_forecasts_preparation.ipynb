# %% [markdown]
# # Preparation of IHME Forecast Data

# %% [markdown]
# ### 20211229_IHME_Forecast_Data.xlsx
# This notebook prepares the IHME Forecast Data from `20211229_IHME_Forecast_Data.xlsx`.

# %%
# Load required packages
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Load data

# %%
# Read in data frame
ihme_forecast = pd.read_excel("../../0_raw_data/novartis_data/20211229_IHME_Forecast_Data.xlsx")

# Look at entire data frame
ihme_forecast
# Out:
#                     Condition     Sex       Age                 Location  \
# 0               Breast cancer    Male  All Ages                   Sweden
# 1               Breast cancer  Female  All Ages                   Sweden
# 2     Malignant skin melanoma    Male  All Ages                   Sweden
# 3     Malignant skin melanoma  Female  All Ages                   Sweden
# 4               Breast cancer    Male  All Ages  Sweden except Stockholm
# ...                       ...     ...       ...                      ...
# 1363  Malignant skin melanoma    Male  All Ages                   Sweden
# 1364  Malignant skin melanoma  Female  All Ages                   Sweden
# 1365  Malignant skin melanoma    Male  All Ages                   Sweden
# 1366  Malignant skin melanoma  Female  All Ages                   Sweden
# 1367  Malignant skin melanoma    Male  All Ages                   Sweden
#
#         Measure                Unit   Forecast Scenario  Year        Value  \
# 0        Deaths              Number       Past estimate  2012    19.060636
# 1        Deaths              Number       Past estimate  2012  1652.227842
# 2        Deaths              Number       Past estimate  2012   331.162019
# 3        Deaths              Number       Past estimate  2012   248.942360
# 4        Deaths              Number       Past estimate  2012    15.235187
# ...         ...                 ...                 ...   ...          ...
# 1363  Incidence  Rate (per 100,000)     Better forecast  2030    48.601690
# 1364  Incidence  Rate (per 100,000)  Reference forecast  2030    31.153374
# 1365  Incidence  Rate (per 100,000)  Reference forecast  2030    44.245966
# 1366  Incidence  Rate (per 100,000)      Worse forecast  2030    30.332263
# 1367  Incidence  Rate (per 100,000)      Worse forecast  2030    41.743119
#
#             Lower        Upper     Data Suite
# 0       16.226380    23.116195  Forecast Data
# 1     1534.316920  1778.104185  Forecast Data
# 2      271.230442   364.941671  Forecast Data
# 3      151.215649   287.126493  Forecast Data
# 4       12.956689    18.975009  Forecast Data
# ...           ...          ...            ...
# 1363          NaN          NaN  Forecast Data
# 1364          NaN          NaN  Forecast Data
# 1365          NaN          NaN  Forecast Data
# 1366          NaN          NaN  Forecast Data
# 1367          NaN          NaN  Forecast Data
#
# [1368 rows x 12 columns]

# %% [markdown]
# ## Preparatory steps

# %%
# Rename all columns
ihme_forecast = ihme_forecast.rename(columns = 
                                     {"Condition": "condition", 
                                      "Sex": "sex", 
                                      "Age": "age", 
                                      "Location": "location",     
                                      "Measure": "measure", 
                                      "Unit": "unit", 
                                      "Forecast Scenario": "forecast_scenario", 
                                      "Year": "year", 
                                      "Value": "value", 
                                      "Lower": "lower", 
                                      "Upper": "upper", 
                                      "Data Suite": "data_suite"})

# %%
# Drop irrelevant columns
ihme_forecast.drop(["age", "data_suite"], axis = 1, inplace = True)

# %%
# Cast to appropriate data type
ihme_forecast["condition"] = ihme_forecast["condition"].astype('category')
ihme_forecast["sex"] = ihme_forecast["sex"].astype('category')
ihme_forecast["location"] = ihme_forecast["location"].astype('category')
ihme_forecast["measure"] = ihme_forecast["measure"].astype('category')
ihme_forecast["unit"] = ihme_forecast["unit"].astype('category')
ihme_forecast["forecast_scenario"] = ihme_forecast["forecast_scenario"].astype('category')
ihme_forecast["year"] = ihme_forecast["year"].astype('int')
ihme_forecast["value"] = ihme_forecast["value"].astype('float')
ihme_forecast["lower"] = ihme_forecast["lower"].astype('float')
ihme_forecast["upper"] = ihme_forecast["upper"].astype('float')

# %%
ihme_forecast
# Out:
#                     condition     sex                 location    measure  \
# 0               Breast cancer    Male                   Sweden     Deaths
# 1               Breast cancer  Female                   Sweden     Deaths
# 2     Malignant skin melanoma    Male                   Sweden     Deaths
# 3     Malignant skin melanoma  Female                   Sweden     Deaths
# 4               Breast cancer    Male  Sweden except Stockholm     Deaths
# ...                       ...     ...                      ...        ...
# 1363  Malignant skin melanoma    Male                   Sweden  Incidence
# 1364  Malignant skin melanoma  Female                   Sweden  Incidence
# 1365  Malignant skin melanoma    Male                   Sweden  Incidence
# 1366  Malignant skin melanoma  Female                   Sweden  Incidence
# 1367  Malignant skin melanoma    Male                   Sweden  Incidence
#
#                     unit   forecast_scenario  year        value        lower  \
# 0                 Number       Past estimate  2012    19.060636    16.226380
# 1                 Number       Past estimate  2012  1652.227842  1534.316920
# 2                 Number       Past estimate  2012   331.162019   271.230442
# 3                 Number       Past estimate  2012   248.942360   151.215649
# 4                 Number       Past estimate  2012    15.235187    12.956689
# ...                  ...                 ...   ...          ...          ...
# 1363  Rate (per 100,000)     Better forecast  2030    48.601690          NaN
# 1364  Rate (per 100,000)  Reference forecast  2030    31.153374          NaN
# 1365  Rate (per 100,000)  Reference forecast  2030    44.245966          NaN
# 1366  Rate (per 100,000)      Worse forecast  2030    30.332263          NaN
# 1367  Rate (per 100,000)      Worse forecast  2030    41.743119          NaN
#
#             upper
# 0       23.116195
# 1     1778.104185
# 2      364.941671
# 3      287.126493
# 4       18.975009
# ...           ...
# 1363          NaN
# 1364          NaN
# 1365          NaN
# 1366          NaN
# 1367          NaN
#
# [1368 rows x 10 columns]

# %%
# Sort data frame 
ihme_forecast = ihme_forecast.sort_values(by = ['condition', 'sex', 'location', 'measure', 'unit', 
                                                'year']).reset_index(drop = True)

# %%
ihme_forecast
# Out:
#                     condition     sex                 location     measure  \
# 0               Breast cancer  Female                Stockholm      Deaths
# 1               Breast cancer  Female                Stockholm      Deaths
# 2               Breast cancer  Female                Stockholm      Deaths
# 3               Breast cancer  Female                Stockholm      Deaths
# 4               Breast cancer  Female                Stockholm      Deaths
# ...                       ...     ...                      ...         ...
# 1363  Malignant skin melanoma    Male  Sweden except Stockholm  Prevalence
# 1364  Malignant skin melanoma    Male  Sweden except Stockholm  Prevalence
# 1365  Malignant skin melanoma    Male  Sweden except Stockholm  Prevalence
# 1366  Malignant skin melanoma    Male  Sweden except Stockholm  Prevalence
# 1367  Malignant skin melanoma    Male  Sweden except Stockholm  Prevalence
#
#                     unit forecast_scenario  year       value       lower  \
# 0                 Number     Past estimate  2012  304.111590  268.215670
# 1                 Number     Past estimate  2013  309.517566  266.763740
# 2                 Number     Past estimate  2014  311.341068  258.490163
# 3                 Number     Past estimate  2015  319.089186  250.521211
# 4                 Number     Past estimate  2016  323.804851  239.637639
# ...                  ...               ...   ...         ...         ...
# 1363  Rate (per 100,000)     Past estimate  2012  160.516613  132.304471
# 1364  Rate (per 100,000)     Past estimate  2013  162.355372  135.270090
# 1365  Rate (per 100,000)     Past estimate  2014  162.523317  135.478271
# 1366  Rate (per 100,000)     Past estimate  2015  165.550626  137.039454
# 1367  Rate (per 100,000)     Past estimate  2016  169.181891  139.402087
#
#            upper
# 0     345.118850
# 1     360.426139
# 2     378.015392
# 3     411.223639
# 4     433.362297
# ...          ...
# 1363  181.866381
# 1364  183.791722
# 1365  182.577034
# 1366  186.263973
# 1367  196.989761
#
# [1368 rows x 10 columns]

# %%
# Save the prepared data frame
route0 = "../processed_data"

if not os.path.exists(route0):
    os.mkdir(route0)
    
print("saving file corresponding to ihme_forecasts.pkl")
ihme_forecast.to_pickle(f"{route0}/ihme_forecasts.pkl")
pd.read_pickle(f"{route0}/ihme_forecasts.pkl")
# Out:
# saving file corresponding to ihme_forecasts.pkl
#                     condition     sex                 location     measure  \
# 0               Breast cancer  Female                Stockholm      Deaths
# 1               Breast cancer  Female                Stockholm      Deaths
# 2               Breast cancer  Female                Stockholm      Deaths
# 3               Breast cancer  Female                Stockholm      Deaths
# 4               Breast cancer  Female                Stockholm      Deaths
# ...                       ...     ...                      ...         ...
# 1363  Malignant skin melanoma    Male  Sweden except Stockholm  Prevalence
# 1364  Malignant skin melanoma    Male  Sweden except Stockholm  Prevalence
# 1365  Malignant skin melanoma    Male  Sweden except Stockholm  Prevalence
# 1366  Malignant skin melanoma    Male  Sweden except Stockholm  Prevalence
# 1367  Malignant skin melanoma    Male  Sweden except Stockholm  Prevalence
#
#                     unit forecast_scenario  year       value       lower  \
# 0                 Number     Past estimate  2012  304.111590  268.215670
# 1                 Number     Past estimate  2013  309.517566  266.763740
# 2                 Number     Past estimate  2014  311.341068  258.490163
# 3                 Number     Past estimate  2015  319.089186  250.521211
# 4                 Number     Past estimate  2016  323.804851  239.637639
# ...                  ...               ...   ...         ...         ...
# 1363  Rate (per 100,000)     Past estimate  2012  160.516613  132.304471
# 1364  Rate (per 100,000)     Past estimate  2013  162.355372  135.270090
# 1365  Rate (per 100,000)     Past estimate  2014  162.523317  135.478271
# 1366  Rate (per 100,000)     Past estimate  2015  165.550626  137.039454
# 1367  Rate (per 100,000)     Past estimate  2016  169.181891  139.402087
#
#            upper
# 0     345.118850
# 1     360.426139
# 2     378.015392
# 3     411.223639
# 4     433.362297
# ...          ...
# 1363  181.866381
# 1364  183.791722
# 1365  182.577034
# 1366  186.263973
# 1367  196.989761
#
# [1368 rows x 10 columns]
