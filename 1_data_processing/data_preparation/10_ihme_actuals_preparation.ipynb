# %% [markdown]
# # Preparation of IHME Actuals Data

# %% [markdown]
# ### 20211229_IHME_GBD2019.xlsx
# This notebook prepares the IHME Actuals Data from `20211229_IHME_GBD2019.xlsx`.

# %%
# Load required packages
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Load data

# %%
# Read in data frame
ihme_actuals = pd.read_excel("../../0_raw_data/novartis_data/20211229_IHME_GBD2019.xlsx")

# Look at entire data frame
ihme_actuals
# Out:
#                                        Condition     Sex       Age  \
# 0                                  Breast cancer    Male  All Ages
# 1                                  Breast cancer  Female  All Ages
# 2                        Malignant skin melanoma    Male  All Ages
# 3                        Malignant skin melanoma  Female  All Ages
# 4                                  Breast cancer    Male  All Ages
# ..                                           ...     ...       ...
# 955            Metastatic phase of breast cancer  Female  All Ages
# 956  Metastatic phase of malignant skin melanoma    Male  All Ages
# 957  Metastatic phase of malignant skin melanoma  Female  All Ages
# 958    Terminal phase of malignant skin melanoma    Male  All Ages
# 959    Terminal phase of malignant skin melanoma  Female  All Ages
#
#                     Location    Measure                Unit  Year  \
# 0                     Sweden     Deaths              Number  2012
# 1                     Sweden     Deaths              Number  2012
# 2                     Sweden     Deaths              Number  2012
# 3                     Sweden     Deaths              Number  2012
# 4    Sweden except Stockholm     Deaths              Number  2012
# ..                       ...        ...                 ...   ...
# 955                   Sweden  Incidence  Rate (per 100,000)  2019
# 956                   Sweden  Incidence  Rate (per 100,000)  2019
# 957                   Sweden  Incidence  Rate (per 100,000)  2019
# 958                   Sweden  Incidence  Rate (per 100,000)  2019
# 959                   Sweden  Incidence  Rate (per 100,000)  2019
#
#            Value        Lower        Upper Data Suite
# 0      11.154988     9.988676    12.488940   GBD 2019
# 1    1952.187085  1775.073238  2072.814309   GBD 2019
# 2     358.542147   183.268982   401.445608   GBD 2019
# 3     256.808232   139.468152   288.756416   GBD 2019
# 4       7.199021     6.190559     8.372396   GBD 2019
# ..           ...          ...          ...        ...
# 955     0.000000     0.000000     0.000000   GBD 2019
# 956     0.000000     0.000000     0.000000   GBD 2019
# 957     0.000000     0.000000     0.000000   GBD 2019
# 958     0.000000     0.000000     0.000000   GBD 2019
# 959     0.000000     0.000000     0.000000   GBD 2019
#
# [960 rows x 11 columns]

# %% [markdown]
# ## Preparatory steps

# %%
# Rename all columns
ihme_actuals = ihme_actuals.rename(columns = 
                                   {"Condition": "condition", 
                                    "Sex": "sex", 
                                    "Age": "age", 
                                    "Location": "location",     
                                    "Measure": "measure", 
                                    "Unit": "unit",  
                                    "Year": "year", 
                                    "Value": "value", 
                                    "Lower": "lower", 
                                    "Upper": "upper", 
                                    "Data Suite": "data_suite"})

# %%
# Drop irrelevant columns
ihme_actuals.drop(["age", "data_suite"], axis = 1, inplace = True)

# %%
# Cast to appropriate data type
ihme_actuals["condition"] = ihme_actuals["condition"].astype('category')
ihme_actuals["sex"] = ihme_actuals["sex"].astype('category')
ihme_actuals["location"] = ihme_actuals["location"].astype('category')
ihme_actuals["measure"] = ihme_actuals["measure"].astype('category')
ihme_actuals["unit"] = ihme_actuals["unit"].astype('category')
ihme_actuals["year"] = ihme_actuals["year"].astype('int')
ihme_actuals["value"] = ihme_actuals["value"].astype('float')
ihme_actuals["lower"] = ihme_actuals["lower"].astype('float')
ihme_actuals["upper"] = ihme_actuals["upper"].astype('float')

# %%
ihme_actuals
# Out:
#                                        condition     sex  \
# 0                                  Breast cancer    Male
# 1                                  Breast cancer  Female
# 2                        Malignant skin melanoma    Male
# 3                        Malignant skin melanoma  Female
# 4                                  Breast cancer    Male
# ..                                           ...     ...
# 955            Metastatic phase of breast cancer  Female
# 956  Metastatic phase of malignant skin melanoma    Male
# 957  Metastatic phase of malignant skin melanoma  Female
# 958    Terminal phase of malignant skin melanoma    Male
# 959    Terminal phase of malignant skin melanoma  Female
#
#                     location    measure                unit  year  \
# 0                     Sweden     Deaths              Number  2012
# 1                     Sweden     Deaths              Number  2012
# 2                     Sweden     Deaths              Number  2012
# 3                     Sweden     Deaths              Number  2012
# 4    Sweden except Stockholm     Deaths              Number  2012
# ..                       ...        ...                 ...   ...
# 955                   Sweden  Incidence  Rate (per 100,000)  2019
# 956                   Sweden  Incidence  Rate (per 100,000)  2019
# 957                   Sweden  Incidence  Rate (per 100,000)  2019
# 958                   Sweden  Incidence  Rate (per 100,000)  2019
# 959                   Sweden  Incidence  Rate (per 100,000)  2019
#
#            value        lower        upper
# 0      11.154988     9.988676    12.488940
# 1    1952.187085  1775.073238  2072.814309
# 2     358.542147   183.268982   401.445608
# 3     256.808232   139.468152   288.756416
# 4       7.199021     6.190559     8.372396
# ..           ...          ...          ...
# 955     0.000000     0.000000     0.000000
# 956     0.000000     0.000000     0.000000
# 957     0.000000     0.000000     0.000000
# 958     0.000000     0.000000     0.000000
# 959     0.000000     0.000000     0.000000
#
# [960 rows x 9 columns]

# %%
# Sort data frame
ihme_actuals = ihme_actuals.sort_values(by = ['condition', 'sex', 'location', 'measure', 'unit', 
                                              'year']).reset_index(drop = True)

# %%
ihme_actuals
# Out:
#                                      condition     sex  \
# 0                                Breast cancer  Female
# 1                                Breast cancer  Female
# 2                                Breast cancer  Female
# 3                                Breast cancer  Female
# 4                                Breast cancer  Female
# ..                                         ...     ...
# 955  Terminal phase of malignant skin melanoma    Male
# 956  Terminal phase of malignant skin melanoma    Male
# 957  Terminal phase of malignant skin melanoma    Male
# 958  Terminal phase of malignant skin melanoma    Male
# 959  Terminal phase of malignant skin melanoma    Male
#
#                     location     measure                unit  year  \
# 0                  Stockholm      Deaths              Number  2012
# 1                  Stockholm      Deaths              Number  2013
# 2                  Stockholm      Deaths              Number  2014
# 3                  Stockholm      Deaths              Number  2015
# 4                  Stockholm      Deaths              Number  2016
# ..                       ...         ...                 ...   ...
# 955  Sweden except Stockholm  Prevalence  Rate (per 100,000)  2015
# 956  Sweden except Stockholm  Prevalence  Rate (per 100,000)  2016
# 957  Sweden except Stockholm  Prevalence  Rate (per 100,000)  2017
# 958  Sweden except Stockholm  Prevalence  Rate (per 100,000)  2018
# 959  Sweden except Stockholm  Prevalence  Rate (per 100,000)  2019
#
#           value       lower       upper
# 0    357.432527  318.807856  386.479973
# 1    360.605135  324.949473  389.527356
# 2    365.016817  323.692779  395.296536
# 3    357.235302  315.816381  388.172419
# 4    366.940581  326.284801  401.275003
# ..          ...         ...         ...
# 955    0.971843    0.505324    1.140718
# 956    0.953051    0.499246    1.127656
# 957    0.953400    0.504011    1.146946
# 958    0.968869    0.501525    1.214614
# 959    0.981410    0.521635    1.326548
#
# [960 rows x 9 columns]

# %%
# Save the prepared data frame
route0 = "../processed_data"

if not os.path.exists(route0):
    os.mkdir(route0)
    
print("saving file corresponding to ihme_actuals.pkl")
ihme_actuals.to_pickle(f"{route0}/ihme_actuals.pkl")
pd.read_pickle(f"{route0}/ihme_actuals.pkl")
# Out:
# saving file corresponding to ihme_actuals.pkl
#                                      condition     sex  \
# 0                                Breast cancer  Female
# 1                                Breast cancer  Female
# 2                                Breast cancer  Female
# 3                                Breast cancer  Female
# 4                                Breast cancer  Female
# ..                                         ...     ...
# 955  Terminal phase of malignant skin melanoma    Male
# 956  Terminal phase of malignant skin melanoma    Male
# 957  Terminal phase of malignant skin melanoma    Male
# 958  Terminal phase of malignant skin melanoma    Male
# 959  Terminal phase of malignant skin melanoma    Male
#
#                     location     measure                unit  year  \
# 0                  Stockholm      Deaths              Number  2012
# 1                  Stockholm      Deaths              Number  2013
# 2                  Stockholm      Deaths              Number  2014
# 3                  Stockholm      Deaths              Number  2015
# 4                  Stockholm      Deaths              Number  2016
# ..                       ...         ...                 ...   ...
# 955  Sweden except Stockholm  Prevalence  Rate (per 100,000)  2015
# 956  Sweden except Stockholm  Prevalence  Rate (per 100,000)  2016
# 957  Sweden except Stockholm  Prevalence  Rate (per 100,000)  2017
# 958  Sweden except Stockholm  Prevalence  Rate (per 100,000)  2018
# 959  Sweden except Stockholm  Prevalence  Rate (per 100,000)  2019
#
#           value       lower       upper
# 0    357.432527  318.807856  386.479973
# 1    360.605135  324.949473  389.527356
# 2    365.016817  323.692779  395.296536
# 3    357.235302  315.816381  388.172419
# 4    366.940581  326.284801  401.275003
# ..          ...         ...         ...
# 955    0.971843    0.505324    1.140718
# 956    0.953051    0.499246    1.127656
# 957    0.953400    0.504011    1.146946
# 958    0.968869    0.501525    1.214614
# 959    0.981410    0.521635    1.326548
#
# [960 rows x 9 columns]
