# %% [markdown]
# # Preparation of Targets

# %% [markdown]
# ### BC & Melanoma targets Sweden.xlsx
# This notebook prepares the targets data from `BC & Melanoma targets Sweden.xlsx`.
#
# We see that the data contains some inconsistencies and eliminate them.

# %%
# Load required packages
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Load data

# %%
# Read in data frame
targets = pd.read_excel("../../0_raw_data/novartis_data/BC & Melanoma targets Sweden.xlsx")

svenska_stader = pd.read_pickle("../processed_data/svenska_stader.pkl")

mapping = pd.read_pickle("../processed_data/mapping.pkl")

# Look at entire data frame
targets
# Out:
#                                                   Name Account Record Type  \
# 0                                  Adel Bader Hamdalla                 HCP
# 1                                        Aglaia Schiza                 HCP
# 2                                Agneta Nordin Danfors                 HCP
# 3                              Ahmed Abbas Albu-Kareem                 HCP
# 4                                          Alaa Haidar                 HCP
# ..                                                 ...                 ...
# 230                                XN Oncology Targets                 NaN
# 231  Copyright (c) 2000-2021 salesforce.com, inc. A...                 NaN
# 232       Confidential Information - Do Not Distribute                 NaN
# 233      Generated By: Aswathi Padman 2021-09-17 12:16                 NaN
# 234                             OnCore - Region Europe                 NaN
#
#     Account Type    Primary Specialty         Primary Parent: Name  \
# 0         Doctor       SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         Doctor       SE-42-Onkologi              Onkologkliniken
# 2         Doctor  SE-1J-Bröstonkologi        Drottningmottagningen
# 3         Doctor       SE-42-Onkologi         Onkologiska kliniken
# 4         Doctor       SE-42-Onkologi          Onkologiska enheten
# ..           ...                  ...                          ...
# 230          NaN                  NaN                          NaN
# 231          NaN                  NaN                          NaN
# 232          NaN                  NaN                          NaN
# 233          NaN                  NaN                          NaN
# 234          NaN                  NaN                          NaN
#
#                     Top Account Name Country: Name Products: Product Name  \
# 0      Södra Älvsborgs Sjukhus Borås            SE                     BC
# 1               Akademiska sjukhuset            SE                     BC
# 2              Drottningmottagningen            SE                     BC
# 3    Universitetssjukhuset Linköping            SE                     BC
# 4          Hallands sjukhus Halmstad            SE                     BC
# ..                               ...           ...                    ...
# 230                              NaN           NaN                    NaN
# 231                              NaN           NaN                    NaN
# 232                              NaN           NaN                    NaN
# 233                              NaN           NaN                    NaN
# 234                              NaN           NaN                    NaN
#
#     Tier Segment Product Metrics Name Created Date  \
# 0     T3      S3         M-0001459248   2021-09-09
# 1     T3      S3         M-0001459249   2021-09-09
# 2     T2      S2         M-0001459250   2021-09-09
# 3     T2      S2         M-0001459251   2021-09-09
# 4     T2      S2         M-0001459252   2021-09-09
# ..   ...     ...                  ...          ...
# 230  NaN     NaN                  NaN          NaT
# 231  NaN     NaN                  NaN          NaT
# 232  NaN     NaN                  NaN          NaT
# 233  NaN     NaN                  NaN          NaT
# 234  NaN     NaN                  NaN          NaT
#
#     Last Modified By: Full Name Last Modified Date NVS_CORE_Sharing_Code  \
# 0      Ronja Moller Christensen         2021-09-09            :XN::SE:::
# 1      Ronja Moller Christensen         2021-09-09            :XN::SE:::
# 2      Ronja Moller Christensen         2021-09-09            :XN::SE:::
# 3      Ronja Moller Christensen         2021-09-09            :XN::SE:::
# 4      Ronja Moller Christensen         2021-09-09            :XN::SE:::
# ..                          ...                ...                   ...
# 230                         NaN                NaT                   NaN
# 231                         NaN                NaT                   NaN
# 232                         NaN                NaT                   NaN
# 233                         NaN                NaT                   NaN
# 234                         NaN                NaT                   NaN
#
#     Product Metrics ID       Account ID   External ID       Salesforce ID
# 0      a0E2o000023IPBH  0012o00002kTDKp  WSEM00021162  0012o00002kTDKpAAO
# 1      a0E2o000023IPBI  0012o00002kTBeA  WSEM00119507  0012o00002kTBeAAAW
# 2      a0E2o000023IPBJ  0012o00002iEZxE  WSEM00027290  0012o00002iEZxEAAW
# 3      a0E2o000023IPBK  0012o00002kTAKC  WSEM00007941  0012o00002kTAKCAA4
# 4      a0E2o000023IPBL  0012o00002iDs1j  WSEM00030426  0012o00002iDs1jAAC
# ..                 ...              ...           ...                 ...
# 230                NaN              NaN           NaN                 NaN
# 231                NaN              NaN           NaN                 NaN
# 232                NaN              NaN           NaN                 NaN
# 233                NaN              NaN           NaN                 NaN
# 234                NaN              NaN           NaN                 NaN
#
# [235 rows x 19 columns]

# %% [markdown]
# ## Preparatory steps

# %%
# Remove all rows with index > 228
targets = targets.loc[0:228, :] # both start and stop of the slice are included

# %%
# Rename all columns
targets = targets.rename(columns = {"Name": "name", "Account Record Type": "account_record_type", "Account Type": 
                                   "account_type", "Primary Specialty": "primary_specialty", "Primary Parent: Name": 
                                   "primary_parent_name", "Top Account Name": "top_account_name", "Country: Name": 
                                   "country_name", "Products: Product Name": "product_name", "Tier": "tier", "Segment": 
                                   "segment", "Product Metrics Name": "product_metrics_name", "Created Date": "created_date", 
                                   "Last Modified By: Full Name": "last_modified_by", "Last Modified Date": 
                                   "last_modified_date", "NVS_CORE_Sharing_Code": "nvs_core_sharing_code", 
                                   "Product Metrics ID": "product_metrics_id", "Account ID": "account_id", "External ID": 
                                   "external_id", "Salesforce ID": "salesforce_id"})

# %%
targets
# Out:
#                         name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name country_name product_name tier segment  \
# 0      Södra Älvsborgs Sjukhus Borås           SE           BC   T3      S3
# 1               Akademiska sjukhuset           SE           BC   T3      S3
# 2              Drottningmottagningen           SE           BC   T2      S2
# 3    Universitetssjukhuset Linköping           SE           BC   T2      S2
# 4          Hallands sjukhus Halmstad           SE           BC   T2      S2
# ..                               ...          ...          ...  ...     ...
# 224    Norrlands Universitetssjukhus           SE     Melanoma   T2      S3
# 225              Länssjukhuset Ryhov           SE           BC   T3      S3
# 226          Centrallasarettet Växjö           SE     Melanoma   T2      S3
# 227              Länssjukhuset Ryhov           SE     Melanoma   T2      S3
# 228     Universitetssjukhuset Örebro           SE     Melanoma   T1      S3
#
#     product_metrics_name created_date          last_modified_by  \
# 0           M-0001459248   2021-09-09  Ronja Moller Christensen
# 1           M-0001459249   2021-09-09  Ronja Moller Christensen
# 2           M-0001459250   2021-09-09  Ronja Moller Christensen
# 3           M-0001459251   2021-09-09  Ronja Moller Christensen
# 4           M-0001459252   2021-09-09  Ronja Moller Christensen
# ..                   ...          ...                       ...
# 224         M-0001458277   2021-09-09  Ronja Moller Christensen
# 225         M-0001459386   2021-09-09  Ronja Moller Christensen
# 226         M-0001458252   2021-09-09  Ronja Moller Christensen
# 227         M-0001458272   2021-09-09  Ronja Moller Christensen
# 228         M-0001458287   2021-09-09  Ronja Moller Christensen
#
#     last_modified_date nvs_core_sharing_code product_metrics_id  \
# 0           2021-09-09            :XN::SE:::    a0E2o000023IPBH
# 1           2021-09-09            :XN::SE:::    a0E2o000023IPBI
# 2           2021-09-09            :XN::SE:::    a0E2o000023IPBJ
# 3           2021-09-09            :XN::SE:::    a0E2o000023IPBK
# 4           2021-09-09            :XN::SE:::    a0E2o000023IPBL
# ..                 ...                   ...                ...
# 224         2021-09-09            :XN::SE:::    a0E2o000023IOvV
# 225         2021-09-09            :XN::SE:::    a0E2o000023IPDV
# 226         2021-09-09            :XN::SE:::    a0E2o000023IOv6
# 227         2021-09-09            :XN::SE:::    a0E2o000023IOvQ
# 228         2021-09-09            :XN::SE:::    a0E2o000023IOvf
#
#           account_id   external_id       salesforce_id
# 0    0012o00002kTDKp  WSEM00021162  0012o00002kTDKpAAO
# 1    0012o00002kTBeA  WSEM00119507  0012o00002kTBeAAAW
# 2    0012o00002iEZxE  WSEM00027290  0012o00002iEZxEAAW
# 3    0012o00002kTAKC  WSEM00007941  0012o00002kTAKCAA4
# 4    0012o00002iDs1j  WSEM00030426  0012o00002iDs1jAAC
# ..               ...           ...                 ...
# 224  0012o00002iEaBJ  WSEM00073634  0012o00002iEaBJAA0
# 225  0012o00002iEYHR  WSEM00088671  0012o00002iEYHRAA4
# 226  0012o00002iETYR  WSEM00047130  0012o00002iETYRAA4
# 227  0012o00002kT9l2  WSEM00003776  0012o00002kT9l2AAC
# 228  0012o00002iETXT  WSEM00040496  0012o00002iETXTAA4
#
# [229 rows x 19 columns]

# %% [markdown]
# We now drop irrelevant variables `country_name`, `product_metrics_name`, `created_date`, `last_modified_by` and `nvs_core_sharing_code`.
#
# There are four identifiers, of which we only retain `product_metrics_id`. We therefore drop `account_id`, `external_id` and `salesforce_id`.

# %%
# Drop irrelevant columns
targets.drop(["country_name", "product_metrics_name", "created_date", "last_modified_by", "last_modified_date",
              "nvs_core_sharing_code", "product_metrics_id", "external_id", "salesforce_id"], axis = 1, inplace = True)

# %%
targets
# Out:
#                         name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name product_name tier segment  \
# 0      Södra Älvsborgs Sjukhus Borås           BC   T3      S3
# 1               Akademiska sjukhuset           BC   T3      S3
# 2              Drottningmottagningen           BC   T2      S2
# 3    Universitetssjukhuset Linköping           BC   T2      S2
# 4          Hallands sjukhus Halmstad           BC   T2      S2
# ..                               ...          ...  ...     ...
# 224    Norrlands Universitetssjukhus     Melanoma   T2      S3
# 225              Länssjukhuset Ryhov           BC   T3      S3
# 226          Centrallasarettet Växjö     Melanoma   T2      S3
# 227              Länssjukhuset Ryhov     Melanoma   T2      S3
# 228     Universitetssjukhuset Örebro     Melanoma   T1      S3
#
#           account_id
# 0    0012o00002kTDKp
# 1    0012o00002kTBeA
# 2    0012o00002iEZxE
# 3    0012o00002kTAKC
# 4    0012o00002iDs1j
# ..               ...
# 224  0012o00002iEaBJ
# 225  0012o00002iEYHR
# 226  0012o00002iETYR
# 227  0012o00002kT9l2
# 228  0012o00002iETXT
#
# [229 rows x 10 columns]

# %%
# Rename certain columns (for merging later on)
targets = targets.rename(columns = {"name": "account_name", "product_name": "indication"})

# %%
targets.dtypes
# Out:
# account_name           object
# account_record_type    object
# account_type           object
# primary_specialty      object
# primary_parent_name    object
# top_account_name       object
# indication             object
# tier                   object
# segment                object
# account_id             object
# dtype: object

# %%
# Cast to appropriate data type
targets["account_name"] = targets["account_name"].astype('str')
targets["account_record_type"] = targets["account_record_type"].astype('category')
targets["account_type"] = targets["account_type"].astype('category')
targets["primary_specialty"] = targets["primary_specialty"].astype('category')
targets["primary_parent_name"] = targets["primary_parent_name"].astype('str')
targets["top_account_name"] = targets["top_account_name"].astype('str')
targets["indication"] = targets["indication"].astype('category')
targets["tier"] = targets["tier"].astype('category')
targets["segment"] = targets["segment"].astype('category')
targets["account_id"] = targets["account_id"].astype('str')
#targets.dtypes

# %%
targets
# Out:
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
# [229 rows x 10 columns]

# %% [markdown]
# ## Data exploration
#
# To get a better impression of the given data, we compile some simple summary statistics and do some data exploration.

# %%
targets.shape
# Out:
# (229, 10)

# %%
targets.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   account_name         229 non-null    object
#  1   account_record_type  229 non-null    category
#  2   account_type         229 non-null    category
#  3   primary_specialty    229 non-null    category
#  4   primary_parent_name  229 non-null    object
#  5   top_account_name     229 non-null    object
#  6   indication           229 non-null    category
#  7   tier                 228 non-null    category
#  8   segment              229 non-null    category
#  9   account_id           229 non-null    object
# dtypes: category(6), object(4)
# memory usage: 9.7+ KB

# %%
# Report some important frequencies
print(f"Frequencies for 'account_record_type':\n{targets.account_record_type.value_counts()}\n") 
print(f"Frequencies for 'account_type':\n{targets.account_type.value_counts()}\n")
print(f"Frequencies for 'primary_specialty':\n{targets.primary_specialty.value_counts()}\n")
print(f"Frequencies for 'indication':\n{targets.indication.value_counts()}\n")
print(f"Frequencies for 'tier':\n{targets.tier.value_counts()}\n")
print(f"Frequencies for 'segment':\n{targets.segment.value_counts()}\n")
# Out:
# Frequencies for 'account_record_type':
# HCP    229
# Name: account_record_type, dtype: int64
#
# Frequencies for 'account_type':
# Doctor    162
# Nurse      67
# Name: account_type, dtype: int64
#
# Frequencies for 'primary_specialty':
# SE-42-Onkologi                 198
# SE-1J-Bröstonkologi             10
# SE-11-Kirurgi                    9
# SE-99-Övrig                      6
# SE-29-Internmedicin              2
# SE-7O-Klinisk farmakologi        1
# SE-7N-Bröstkirurgi               1
# SE-1Y-Gynekologisk onkologi      1
# SE-03-Klinisk patologi           1
# Name: primary_specialty, dtype: int64
#
# Frequencies for 'indication':
# BC          147
# Melanoma     82
# Name: indication, dtype: int64
#
# Frequencies for 'tier':
# T2    84
# T3    83
# T1    27
# T4    21
# NT    11
# ST     2
# Name: tier, dtype: int64
#
# Frequencies for 'segment':
# S3    93
# S4    66
# S2    54
# S1    16
# Name: segment, dtype: int64

# %%
# number of duplicates
print(targets.duplicated().sum())
print(targets['account_name'].duplicated().sum())
# Out:
# 0
# 21

# %%
# show duplicates in terms of account_name
targets[targets.duplicated(subset=['account_name'])]
# Out:
#                account_name account_record_type account_type  \
# 128           Aglaia Schiza                 HCP       Doctor
# 136        Kilian Bachmeier                 HCP       Doctor
# 137              Per Edlund                 HCP       Doctor
# 141         Johan Falkenius                 HCP       Doctor
# 146        Magnus Lagerlund                 HCP       Doctor
# 147     Charlotte Bratthäll                 HCP       Doctor
# 149        Andreas Nearchou                 HCP       Doctor
# 152              Sara Wirén                 HCP       Doctor
# 159       Antonios Valachis                 HCP       Doctor
# 161         Kenneth Villman                 HCP       Doctor
# 162          Greger Nilsson                 HCP       Doctor
# 163         Cecilia Nilsson                 HCP       Doctor
# 167               Pär Bodén                 HCP       Doctor
# 172       Gudrun Linderkers                 HCP        Nurse
# 174          Carin Lundgren                 HCP        Nurse
# 178            Anna Askelin                 HCP        Nurse
# 179                Eva Ulff                 HCP        Nurse
# 205      Elsy-Britt Schildt                 HCP       Doctor
# 216      Olga Del Val Munoz                 HCP       Doctor
# 220            Sara Kinhult                 HCP       Doctor
# 224  Ylva Holmgren Stenlund                 HCP       Doctor
#
#     primary_specialty                     primary_parent_name  \
# 128    SE-42-Onkologi                         Onkologkliniken
# 136    SE-42-Onkologi                         Onkologkliniken
# 137    SE-42-Onkologi                         Onkologkliniken
# 141    SE-42-Onkologi     ME Huvud- hals- lung- och hudcancer
# 146    SE-42-Onkologi                         Onkologienheten
# 147    SE-42-Onkologi                         Onkologienheten
# 149    SE-42-Onkologi                Onkologkliniken Sörmland
# 152    SE-42-Onkologi                           Cancercentrum
# 159    SE-42-Onkologi                    Onkologiska kliniken
# 161    SE-42-Onkologi                    Onkologiska kliniken
# 162    SE-42-Onkologi                          Onkologenheten
# 163    SE-42-Onkologi                        Onkologikliniken
# 167    SE-42-Onkologi                       Onkologmottagning
# 172    SE-42-Onkologi                     Onkologmottagningen
# 174    SE-42-Onkologi                         Onkologkliniken
# 178    SE-42-Onkologi                         Onkologienheten
# 179    SE-42-Onkologi                         Onkologkliniken
# 205    SE-42-Onkologi                         Onkologienheten
# 216    SE-42-Onkologi                         Onkologkliniken
# 220    SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 224    SE-42-Onkologi                           Cancercentrum
#
#                     top_account_name indication tier segment       account_id
# 128             Akademiska sjukhuset   Melanoma   T2      S3  0012o00002kTBeA
# 136      Centralsjukhuset i Karlstad   Melanoma   T3      S3  0012o00002iEVn6
# 137                    Gävle Sjukhus   Melanoma   T3      S3  0012o00002kTDCr
# 141        Karolinska Univ Sjh Solna   Melanoma   T2      S2  0012o00002iETVR
# 146           Länssjukhuset i Kalmar   Melanoma   T2      S2  0012o00002iESPQ
# 147           Länssjukhuset i Kalmar   Melanoma   T3      S3  0012o00002iEU4H
# 149                   Mälarsjukhuset   Melanoma   T2      S3  0012o00002iEcW0
# 152    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002kTELw
# 159     Universitetssjukhuset Örebro   Melanoma   T1      S2  0012o00002iEVfq
# 161     Universitetssjukhuset Örebro   Melanoma   T2      S2  0012o00002kTArl
# 162                   Visby lasarett   Melanoma   T2      S3  0012o00002kTCqX
# 163    Västmanlands sjukhus Västerås   Melanoma   T1      S2  0012o00002iEZpE
# 167               Östersunds Sjukhus   Melanoma   T2      S3  0012o00002iEc7V
# 172                    Falu Lasarett   Melanoma   T2      S4  0012o00002kTEV0
# 174                    Gävle Sjukhus   Melanoma   T2      S4  0012o00002iEQGC
# 178           Länssjukhuset i Kalmar   Melanoma   T2      S4  0012o00002kTCYp
# 179              Länssjukhuset Ryhov   Melanoma   T2      S4  0012o00002kT9SQ
# 205           Länssjukhuset i Kalmar   Melanoma   T1      S2  0012o00002iETWi
# 216                    Gävle Sjukhus   Melanoma   T1      S2  0012o00002iEaJM
# 220  Skånes Universitetssjukhus Lund   Melanoma   T2      S2  0012o00002iEcCc
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ

# %%
# show duplicates and originals
df = pd.DataFrame(columns = targets.columns)
for x in targets[targets.duplicated(subset = "account_name", keep = 'first')]["account_name"]:
    df = df.append(targets[targets["account_name"] == x])

df
# Out:
#                account_name account_record_type account_type  \
# 1             Aglaia Schiza                 HCP       Doctor
# 128           Aglaia Schiza                 HCP       Doctor
# 70         Kilian Bachmeier                 HCP       Doctor
# 136        Kilian Bachmeier                 HCP       Doctor
# 99               Per Edlund                 HCP       Doctor
# 137              Per Edlund                 HCP       Doctor
# 122         Johan Falkenius                 HCP       Doctor
# 141         Johan Falkenius                 HCP       Doctor
# 77         Magnus Lagerlund                 HCP       Doctor
# 146        Magnus Lagerlund                 HCP       Doctor
# 26      Charlotte Bratthäll                 HCP       Doctor
# 147     Charlotte Bratthäll                 HCP       Doctor
# 6          Andreas Nearchou                 HCP       Doctor
# 149        Andreas Nearchou                 HCP       Doctor
# 120              Sara Wirén                 HCP       Doctor
# 152              Sara Wirén                 HCP       Doctor
# 17        Antonios Valachis                 HCP       Doctor
# 159       Antonios Valachis                 HCP       Doctor
# 67          Kenneth Villman                 HCP       Doctor
# 161         Kenneth Villman                 HCP       Doctor
# 48           Greger Nilsson                 HCP       Doctor
# 162          Greger Nilsson                 HCP       Doctor
# 24          Cecilia Nilsson                 HCP       Doctor
# 163         Cecilia Nilsson                 HCP       Doctor
# 95                Pär Bodén                 HCP       Doctor
# 167               Pär Bodén                 HCP       Doctor
# 81        Gudrun Linderkers                 HCP        Nurse
# 172       Gudrun Linderkers                 HCP        Nurse
# 68           Carin Lundgren                 HCP        Nurse
# 174          Carin Lundgren                 HCP        Nurse
# 52             Anna Askelin                 HCP        Nurse
# 178            Anna Askelin                 HCP        Nurse
# 72                 Eva Ulff                 HCP        Nurse
# 179                Eva Ulff                 HCP        Nurse
# 204      Elsy-Britt Schildt                 HCP       Doctor
# 205      Elsy-Britt Schildt                 HCP       Doctor
# 215      Olga Del Val Munoz                 HCP       Doctor
# 216      Olga Del Val Munoz                 HCP       Doctor
# 219            Sara Kinhult                 HCP       Doctor
# 220            Sara Kinhult                 HCP       Doctor
# 223  Ylva Holmgren Stenlund                 HCP       Doctor
# 224  Ylva Holmgren Stenlund                 HCP       Doctor
#
#     primary_specialty                     primary_parent_name  \
# 1      SE-42-Onkologi                         Onkologkliniken
# 128    SE-42-Onkologi                         Onkologkliniken
# 70     SE-42-Onkologi                         Onkologkliniken
# 136    SE-42-Onkologi                         Onkologkliniken
# 99     SE-42-Onkologi                         Onkologkliniken
# 137    SE-42-Onkologi                         Onkologkliniken
# 122    SE-42-Onkologi     ME Huvud- hals- lung- och hudcancer
# 141    SE-42-Onkologi     ME Huvud- hals- lung- och hudcancer
# 77     SE-42-Onkologi                         Onkologienheten
# 146    SE-42-Onkologi                         Onkologienheten
# 26     SE-42-Onkologi                         Onkologienheten
# 147    SE-42-Onkologi                         Onkologienheten
# 6      SE-42-Onkologi                Onkologkliniken Sörmland
# 149    SE-42-Onkologi                Onkologkliniken Sörmland
# 120    SE-42-Onkologi                           Cancercentrum
# 152    SE-42-Onkologi                           Cancercentrum
# 17     SE-42-Onkologi                    Onkologiska kliniken
# 159    SE-42-Onkologi                    Onkologiska kliniken
# 67     SE-42-Onkologi                    Onkologiska kliniken
# 161    SE-42-Onkologi                    Onkologiska kliniken
# 48     SE-42-Onkologi                          Onkologenheten
# 162    SE-42-Onkologi                          Onkologenheten
# 24     SE-42-Onkologi                        Onkologikliniken
# 163    SE-42-Onkologi                        Onkologikliniken
# 95     SE-42-Onkologi                       Onkologmottagning
# 167    SE-42-Onkologi                       Onkologmottagning
# 81     SE-42-Onkologi                     Onkologmottagningen
# 172    SE-42-Onkologi                     Onkologmottagningen
# 68     SE-42-Onkologi                         Onkologkliniken
# 174    SE-42-Onkologi                         Onkologkliniken
# 52     SE-42-Onkologi                         Onkologienheten
# 178    SE-42-Onkologi                         Onkologienheten
# 72     SE-42-Onkologi                         Onkologkliniken
# 179    SE-42-Onkologi                         Onkologkliniken
# 204    SE-42-Onkologi                         Onkologienheten
# 205    SE-42-Onkologi                         Onkologienheten
# 215    SE-42-Onkologi                         Onkologkliniken
# 216    SE-42-Onkologi                         Onkologkliniken
# 219    SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 220    SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 223    SE-42-Onkologi                           Cancercentrum
# 224    SE-42-Onkologi                           Cancercentrum
#
#                     top_account_name indication tier segment       account_id
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 128             Akademiska sjukhuset   Melanoma   T2      S3  0012o00002kTBeA
# 70       Centralsjukhuset i Karlstad         BC   T3      S3  0012o00002iEVn6
# 136      Centralsjukhuset i Karlstad   Melanoma   T3      S3  0012o00002iEVn6
# 99                     Gävle Sjukhus         BC   T2      S2  0012o00002kTDCr
# 137                    Gävle Sjukhus   Melanoma   T3      S3  0012o00002kTDCr
# 122        Karolinska Univ Sjh Solna         BC   T2      S2  0012o00002iETVR
# 141        Karolinska Univ Sjh Solna   Melanoma   T2      S2  0012o00002iETVR
# 77            Länssjukhuset i Kalmar         BC   T2      S2  0012o00002iESPQ
# 146           Länssjukhuset i Kalmar   Melanoma   T2      S2  0012o00002iESPQ
# 26            Länssjukhuset i Kalmar         BC   T2      S2  0012o00002iEU4H
# 147           Länssjukhuset i Kalmar   Melanoma   T3      S3  0012o00002iEU4H
# 6                     Mälarsjukhuset         BC   T2      S2  0012o00002iEcW0
# 149                   Mälarsjukhuset   Melanoma   T2      S3  0012o00002iEcW0
# 120    Norrlands Universitetssjukhus         BC   T3      S3  0012o00002kTELw
# 152    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002kTELw
# 17      Universitetssjukhuset Örebro         BC   T1      S1  0012o00002iEVfq
# 159     Universitetssjukhuset Örebro   Melanoma   T1      S2  0012o00002iEVfq
# 67      Universitetssjukhuset Örebro         BC   T2      S2  0012o00002kTArl
# 161     Universitetssjukhuset Örebro   Melanoma   T2      S2  0012o00002kTArl
# 48                    Visby lasarett         BC   T2      S2  0012o00002kTCqX
# 162                   Visby lasarett   Melanoma   T2      S3  0012o00002kTCqX
# 24     Västmanlands sjukhus Västerås         BC   T2      S2  0012o00002iEZpE
# 163    Västmanlands sjukhus Västerås   Melanoma   T1      S2  0012o00002iEZpE
# 95                Östersunds Sjukhus         BC   T2      S2  0012o00002iEc7V
# 167               Östersunds Sjukhus   Melanoma   T2      S3  0012o00002iEc7V
# 81                     Falu Lasarett         BC   T4      S4  0012o00002kTEV0
# 172                    Falu Lasarett   Melanoma   T2      S4  0012o00002kTEV0
# 68                     Gävle Sjukhus         BC   T4      S4  0012o00002iEQGC
# 174                    Gävle Sjukhus   Melanoma   T2      S4  0012o00002iEQGC
# 52            Länssjukhuset i Kalmar         BC   T4      S4  0012o00002kTCYp
# 178           Länssjukhuset i Kalmar   Melanoma   T2      S4  0012o00002kTCYp
# 72               Länssjukhuset Ryhov         BC   NT      S4  0012o00002kT9SQ
# 179              Länssjukhuset Ryhov   Melanoma   T2      S4  0012o00002kT9SQ
# 204           Länssjukhuset i Kalmar         BC   T3      S3  0012o00002iETWi
# 205           Länssjukhuset i Kalmar   Melanoma   T1      S2  0012o00002iETWi
# 215                    Gävle Sjukhus         BC   T2      S2  0012o00002iEaJM
# 216                    Gävle Sjukhus   Melanoma   T1      S2  0012o00002iEaJM
# 219  Skånes Universitetssjukhus Lund         BC   T3      S3  0012o00002iEcCc
# 220  Skånes Universitetssjukhus Lund   Melanoma   T2      S2  0012o00002iEcCc
# 223    Norrlands Universitetssjukhus         BC   T3      S3  0012o00002iEaBJ
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ

# %%
# Are nurses always S4?
targets[targets['account_type'] == 'Nurse']
# Out:
#                    account_name account_record_type account_type  \
# 7              Ulrika Bergqvist                 HCP        Nurse
# 9           Elisabeth Ryd Ausén                 HCP        Nurse
# 10             Marie Santonsson                 HCP        Nurse
# 15   Anna Maria Hasselgren Häll                 HCP        Nurse
# 18            Elisabet Karlsson                 HCP        Nurse
# ..                          ...                 ...          ...
# 202               Lola Svensson                 HCP        Nurse
# 209            Harriet Axelsson                 HCP        Nurse
# 212              Carina Larsson                 HCP        Nurse
# 213              Karin Lycknert                 HCP        Nurse
# 222             Maria Gränström                 HCP        Nurse
#
#       primary_specialty                  primary_parent_name  \
# 7         SE-11-Kirurgi               Avd 8 Kirurg- ortopedi
# 9         SE-11-Kirurgi                         Bröstcentrum
# 10        SE-11-Kirurgi        Kirurg och Urologmottagningen
# 15       SE-42-Onkologi             Aleris Christinakliniken
# 18       SE-42-Onkologi                        Cancercentrum
# ..                  ...                                  ...
# 202      SE-42-Onkologi  Kirurgklinikens onkologiska dagvård
# 209      SE-42-Onkologi                       Onkologenheten
# 212      SE-42-Onkologi             Onkologkliniken Sörmland
# 213      SE-42-Onkologi                  Onkologmottagningen
# 222  SE-7N-Bröstkirurgi                         Bröstcentrum
#
#                    top_account_name indication tier segment       account_id
# 7               Skellefteå Lasarett         BC   T4      S4  0012o00002iEdBr
# 9       Capio S:t Görans Sjukhus AB         BC   T4      S4  0012o00002iEVPo
# 10   Blekingesjukhuset i Karlskrona         BC   NT      S4  0012o00002iEcUJ
# 15                  Sophiahemmet AB         BC   T4      S4  0012o00002iEQSf
# 18    Norrlands Universitetssjukhus         BC   T4      S4  0012o00002kT9HL
# ..                              ...        ...  ...     ...              ...
# 202  Blekingesjukhuset i Karlskrona         BC   NT      S4  0012o00002iEbln
# 209               Uddevalla sjukhus         BC   NT      S4  0012o00002iEUUU
# 212                  Mälarsjukhuset         BC   T4      S4  0012o00002iET13
# 213        Hallands sjukhus Varberg         BC   NT      S4  0012o00002iEbhJ
# 222     Capio S:t Görans Sjukhus AB         BC   T4      S4  0012o00002iETWb
#
# [67 rows x 10 columns]

# %%
print(targets[targets['account_type'] == 'Nurse']['tier'].unique())
print(targets[targets['account_type'] == 'Doctor']['tier'].unique())
# Out:
# ['T4', 'NT', 'T3', 'T2', 'T1']
# Categories (5, object): ['T4', 'NT', 'T3', 'T2', 'T1']
# ['T3', 'T2', 'T1', NaN, 'ST']
# Categories (4, object): ['T3', 'T2', 'T1', 'ST']

# %%
print(targets[targets['account_type'] == 'Nurse']['segment'].unique())
print(targets[targets['account_type'] == 'Doctor']['segment'].unique())
# Out:
# ['S4', 'S3']
# Categories (2, object): ['S4', 'S3']
# ['S3', 'S2', 'S1', 'S4']
# Categories (4, object): ['S3', 'S2', 'S1', 'S4']

# %% [markdown]
# Observations by variable:
#
# * `account_name`: 21 doctors/nurses show up twice: both as BC and Melanoma doctor/nurse. A doctor/nurse only changes in terms of indication, can change in terms of tier (doctors/nurses) and segment (only doctors, nurses never change in terms of segment), but never changes in terms of account_type, primary_specialty, primary_parent_name, top_account_name, account_id.
# * `account_record_type`: It always takes the value 'HCP' to indicate the doctor/nurse is a health care provider.
# * `account_type`: An HCP can be a doctor (162/229) or a nurse (67/229).
# * `primary_specialty`: 9 categories, 'SE-42 Onkologi' is the most common.
# * `primary_parent_name`: Seems to indicate the ward that a doctor/nurses works on. However, it sometimes also contains the hospital's name, e.g., where 'SE-Arbetsplats okänd' is given as top_account_name. In this case, we have that the top_account_name is 'Capio S:t Görans Sjukhus AB'.
# * `top_account_name`: Indication of hospital that a doctor/nurse works at. However, it sometimes also contains entries which do not refer to a hospital, e.g., 'SE-Arbetsplats okänd'. In some of these cases, the hospital may be found in primary_parent_name, in other cases, further research might be required.
# * `indication`: An HCP can be assigned to either BC (147/229) or Melanoma (82/229). 21 HCPs are assigned to both categories.
# * `tier`: T2 and T3 most common, one missing value. Nurses can be T1, T2, T3, T4, NT. Doctors can be T1, T2, T3, ST. (One missing value for a doctor.)
# * `segment`: S3 most common. Nurses can be S3 or S4. Doctors can be S1, S2, S3 or S4.
# * `account_id`: Unique identifier for each doctor/nurse, is of course unchanged by whether a doctor/nurse is associated with BC or Melanoma.

# %%
targets
# Out:
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
# [229 rows x 10 columns]

# %% [markdown]
# ## Additional preparatory steps by variable
#
# In the following, we predominantly correct inconsistencies in the data.

# %% [markdown]
# ### `top_account_name`

# %% [markdown]
# Let us first take a look at the different hospitals given in `top_account_name`.

# %%
targets['top_account_name'].unique().tolist()
# Out:
# ['Södra Älvsborgs Sjukhus Borås',
#  'Akademiska sjukhuset',
#  'Drottningmottagningen',
#  'Universitetssjukhuset Linköping',
#  'Hallands sjukhus Halmstad',
#  'Lunds Universitet',
#  'Mälarsjukhuset',
#  'Skellefteå Lasarett',
#  'Universitetssjukhuset Örebro',
#  'Capio S:t Görans Sjukhus AB',
#  'Blekingesjukhuset i Karlskrona',
#  'Södersjukhuset',
#  'Uddevalla sjukhus',
#  'Länssjh Sundsvall-Härnösand',
#  'Sophiahemmet AB',
#  'Norrlands Universitetssjukhus',
#  'Sahlgrenska Univ sjh',
#  'Skånes Universitetssjukhus Malmö',
#  'Västmanlands sjukhus Västerås',
#  'Länssjukhuset i Kalmar',
#  'Skånes Universitetssjukhus Lund',
#  'SE-Arbetsplats okänd',
#  'Karolinska Univ Sjh Solna',
#  'Visby lasarett',
#  'Länssjukhuset Ryhov',
#  'Samverkansnämnden Uppsala Örebro sjv reg',
#  'Johan Hartman',
#  'Gävle Sjukhus',
#  'Centralsjukhuset i Karlstad',
#  'Centrallasarettet Växjö',
#  'Falu Lasarett',
#  'Skaraborgs Sjh Lidköping',
#  'Helsingborgs lasarett',
#  'Östersunds Sjukhus',
#  'Per Karlsson Oncology Consulting',
#  'TLV Tandvårds & läkemedelsförmånsverket',
#  'Skaraborgs Sjukhus Skövde',
#  'Hallands sjukhus Varberg',
#  'Olof Bjarnadottir']

# %% [markdown]
# This list contains a few elements that do not refer to a hospital nor to another institution:
# * 'SE-Arbetsplats okänd': workplace unknown
# *  'Samverkansnämnden Uppsala Örebro sjv reg' -> This is a healthcare region but no hospital. Look [here](https://www.xn--sjukvrdsregionmellan-0zb.se/).
# * 'Johan Hartman': name of HCP -> He works in Solna.
# * 'Per Karlsson Oncology Consulting': holds a position as full Professor of Oncology at Sahlgrenska Academy, combined with a position as Senior Consultant in Oncology and Chief Physician at Sahlgrenska University Hospital. Look [here](https://www.gu.se/en/research/breast-cancer-research-per-karlsson-group).
# * 'TLV Tandvårds & läkemedelsförmånsverket': The Dental and Pharmaceutical Benefits Agency, TLV, is a central government agency whose remit is to determine whether a pharmaceutical product, medical device or dental care procedure shall be subsidized by the state. We also determine retail margins for all pharmacies in Sweden, regulate the substitution of medicines at the pharmacies and supervise certain areas of the pharmaceutical market. Look [here](https://www.tlv.se/in-english.html).
# * 'Olof Bjarnadottir': name of HCP. Olof Bjarnadottir is affiliated with Lund University and is actually called Olöf Bjarnadottir. Look [here](https://portal.research.lu.se/en/persons/ol%C3%B6f-bjarnadottir).
#
# Let us now take a closer look at these cases.

# %% [markdown]
# #### SE-Arbetsplats okänd

# %%
targets[targets['top_account_name'] == 'SE-Arbetsplats okänd']
# Out:
#                     account_name account_record_type account_type  \
# 28  Christina Linder Stragliotto                 HCP       Doctor
# 42              Evangelos Digkas                 HCP       Doctor
# 46               Gilberto Morgan                 HCP       Doctor
# 93           Nils-Olof Bengtsson                 HCP       Doctor
#
#    primary_specialty          primary_parent_name      top_account_name  \
# 28       SE-99-Övrig  Capio S:t Görans Sjukhus AB  SE-Arbetsplats okänd
# 42       SE-99-Övrig  Capio S:t Görans Sjukhus AB  SE-Arbetsplats okänd
# 46       SE-99-Övrig  Capio S:t Görans Sjukhus AB  SE-Arbetsplats okänd
# 93       SE-99-Övrig  Capio S:t Görans Sjukhus AB  SE-Arbetsplats okänd
#
#    indication tier segment       account_id
# 28         BC   T2      S2  0012o00002kTn1e
# 42         BC   T3      S3  0012o00002iEYoc
# 46         BC   T3      S3  0012o00002kTn3G
# 93         BC   T3      S3  0012o00002iEWxt

# %% [markdown]
# We now take a look if any other information on these doctors is given.

# %%
targets[targets['account_name'] == 'Christina Linder Stragliotto']
# Out:
#                     account_name account_record_type account_type  \
# 28  Christina Linder Stragliotto                 HCP       Doctor
#
#    primary_specialty          primary_parent_name      top_account_name  \
# 28       SE-99-Övrig  Capio S:t Görans Sjukhus AB  SE-Arbetsplats okänd
#
#    indication tier segment       account_id
# 28         BC   T2      S2  0012o00002kTn1e

# %%
targets[targets['account_name'] == 'Evangelos Digkas']
# Out:
#         account_name account_record_type account_type primary_specialty  \
# 42  Evangelos Digkas                 HCP       Doctor       SE-99-Övrig
#
#             primary_parent_name      top_account_name indication tier segment  \
# 42  Capio S:t Görans Sjukhus AB  SE-Arbetsplats okänd         BC   T3      S3
#
#          account_id
# 42  0012o00002iEYoc

# %%
targets[targets['account_name'] == 'Gilberto Morgan']
# Out:
#        account_name account_record_type account_type primary_specialty  \
# 46  Gilberto Morgan                 HCP       Doctor       SE-99-Övrig
#
#             primary_parent_name      top_account_name indication tier segment  \
# 46  Capio S:t Görans Sjukhus AB  SE-Arbetsplats okänd         BC   T3      S3
#
#          account_id
# 46  0012o00002kTn3G

# %%
targets[targets['account_name'] == 'Nils-Olof Bengtsson']
# Out:
#            account_name account_record_type account_type primary_specialty  \
# 93  Nils-Olof Bengtsson                 HCP       Doctor       SE-99-Övrig
#
#             primary_parent_name      top_account_name indication tier segment  \
# 93  Capio S:t Görans Sjukhus AB  SE-Arbetsplats okänd         BC   T3      S3
#
#          account_id
# 93  0012o00002iEWxt

# %% [markdown]
# No futher information than the one given by filtering for 'SE-Arbetsplats okänd' is given. But we know which hospital they work at either way. So, SE-Arbetsplats okänd can be replaced by 'Capio S:t Görans Sjukhus AB'.

# %% [markdown]
# #### Samverkansnämnden Uppsala Örebro sjv reg

# %%
targets[targets['top_account_name'] == 'Samverkansnämnden Uppsala Örebro sjv reg']
# Out:
#      account_name account_record_type account_type primary_specialty  \
# 58  Johan Ahlgren                 HCP       Doctor       SE-99-Övrig
#
#    primary_parent_name                          top_account_name indication  \
# 58         Styrgruppen  Samverkansnämnden Uppsala Örebro sjv reg         BC
#
#    tier segment       account_id
# 58   T2      S2  0012o00002iEWKi

# %%
targets[targets['account_name'] == 'Johan Ahlgren']
# Out:
#      account_name account_record_type account_type primary_specialty  \
# 58  Johan Ahlgren                 HCP       Doctor       SE-99-Övrig
#
#    primary_parent_name                          top_account_name indication  \
# 58         Styrgruppen  Samverkansnämnden Uppsala Örebro sjv reg         BC
#
#    tier segment       account_id
# 58   T2      S2  0012o00002iEWKi

# %% [markdown]
# Johan Ahlgren works at Akademiska Sjukhuset Uppsala. Look [here](https://orcid.org/0000-0001-6392-273X).

# %% [markdown]
# #### Johan Hartman

# %%
targets[targets['account_name'] == 'Johan Hartman']
# Out:
#      account_name account_record_type account_type       primary_specialty  \
# 59  Johan Hartman                 HCP       Doctor  SE-03-Klinisk patologi
#
#                        primary_parent_name top_account_name indication tier  \
# 59  ME Klinisk patologi och cytologi Solna    Johan Hartman         BC   T1
#
#    segment       account_id
# 59      S1  0012o00002iEVWw

# %% [markdown]
# He works in Solna. ME Klinisk patologi och cytologi Solna belongs to Karolinska Universitetssjukhuset, which is already in the data as 'Karolinska Univ Sjh Solna'.

# %% [markdown]
# #### Per Karlsson Oncology Consulting

# %%
targets[targets['account_name'] == 'Per Karlsson']
# Out:
#      account_name account_record_type account_type primary_specialty  \
# 100  Per Karlsson                 HCP       Doctor    SE-42-Onkologi
#
#                   primary_parent_name                  top_account_name  \
# 100  Per Karlsson Oncology Consulting  Per Karlsson Oncology Consulting
#
#     indication tier segment       account_id
# 100         BC   T1      S1  0012o00002kTDQh

# %% [markdown]
# Per Karlsson works at Sahlgrenska Universitetssjukhuset, which is already in the data as 'Sahlgrenska Univ sjh'. Look [here](https://www.gu.se/en/about/find-staff/perkarlsson).

# %% [markdown]
# #### TLV Tandvårds & läkemedelsförmånsverket

# %%
targets[targets['top_account_name'] == 'TLV Tandvårds & läkemedelsförmånsverket']
# Out:
#          account_name account_record_type account_type primary_specialty  \
# 106  Roger Henriksson                 HCP       Doctor    SE-42-Onkologi
#
#              primary_parent_name                         top_account_name  \
# 106  Vetenskapliga råd Läkemedel  TLV Tandvårds & läkemedelsförmånsverket
#
#     indication tier segment       account_id
# 106         BC   T3      S3  0012o00002iEY4D

# %% [markdown]
# Roger Henriksson works at Norrlands Universitetssjukhus. Look [here](https://www.umu.se/en/staff/roger-henriksson/).

# %% [markdown]
# #### Olof Bjarnadottir

# %%
targets[targets['account_name'] == 'Olof Bjarnadottir']
# Out:
#           account_name account_record_type account_type primary_specialty  \
# 217  Olof Bjarnadottir                 HCP       Doctor    SE-42-Onkologi
#
#     primary_parent_name   top_account_name indication tier segment  \
# 217                 nan  Olof Bjarnadottir         BC   T3      S3
#
#           account_id
# 217  0012o00002iER0W

# %% [markdown]
# Olof Bjarnadottir, actually Olöf Bjarnadottir, is working at Lunds Universitet. Look [here](https://portal.research.lu.se/en/persons/ol%C3%B6f-bjarnadottir).

# %% [markdown]
# With the information found out above, we now do the necessary changes.

# %%
# Replace 'SE-Arbetsplats okänd' by 'Capio S:t Görans Sjukhus AB'
targets['top_account_name'] = targets['top_account_name'].str.replace("SE-Arbetsplats okänd", "Capio S:t Görans Sjukhus AB")
# Replace 'Samverkansnämnden Uppsala Örebro sjv reg' by 'Akademiska sjukhuset'
targets['top_account_name'] = targets['top_account_name'].str.replace("Samverkansnämnden Uppsala Örebro sjv reg", "Akademiska sjukhuset")
# Replace 'Johan Hartman' by 'Karolinska Univ Sjh Solna'
targets['top_account_name'] = targets['top_account_name'].str.replace("Johan Hartman", "Karolinska Univ Sjh Solna")
# Replace 'Per Karlsson Oncology Conslting' by 'Sahlgrenska Univ sjh'
targets['top_account_name'] = targets['top_account_name'].str.replace("Per Karlsson Oncology Consulting", "Sahlgrenska Univ sjh")
# Replace 'TLV Tandvårds & läkemedelsförmånsverket' by 'Norrlands Universitetssjukhus'
targets['top_account_name'] = targets['top_account_name'].str.replace("TLV Tandvårds & läkemedelsförmånsverket", "Norrlands Universitetssjukhus")
# Replace 'Olof Bjarnadottir' by 'Lunds Universitet'
targets['top_account_name'] = targets['top_account_name'].str.replace("Olof Bjarnadottir", "Lunds Universitet")

# %%
targets
# Out:
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
# [229 rows x 10 columns]

# %% [markdown]
# Check that SE-Arbetsplats okänd, Samverkansnämnden Uppsala Örebro sjv reg, Johan Hartman, Per Karlsson Oncology Consulting, TLV Tandvårds & läkemedelsförmånsverket, Olof Bjarnadottir are no longer present.

# %%
targets['top_account_name'].unique().tolist()
# Out:
# ['Södra Älvsborgs Sjukhus Borås',
#  'Akademiska sjukhuset',
#  'Drottningmottagningen',
#  'Universitetssjukhuset Linköping',
#  'Hallands sjukhus Halmstad',
#  'Lunds Universitet',
#  'Mälarsjukhuset',
#  'Skellefteå Lasarett',
#  'Universitetssjukhuset Örebro',
#  'Capio S:t Görans Sjukhus AB',
#  'Blekingesjukhuset i Karlskrona',
#  'Södersjukhuset',
#  'Uddevalla sjukhus',
#  'Länssjh Sundsvall-Härnösand',
#  'Sophiahemmet AB',
#  'Norrlands Universitetssjukhus',
#  'Sahlgrenska Univ sjh',
#  'Skånes Universitetssjukhus Malmö',
#  'Västmanlands sjukhus Västerås',
#  'Länssjukhuset i Kalmar',
#  'Skånes Universitetssjukhus Lund',
#  'Karolinska Univ Sjh Solna',
#  'Visby lasarett',
#  'Länssjukhuset Ryhov',
#  'Gävle Sjukhus',
#  'Centralsjukhuset i Karlstad',
#  'Centrallasarettet Växjö',
#  'Falu Lasarett',
#  'Skaraborgs Sjh Lidköping',
#  'Helsingborgs lasarett',
#  'Östersunds Sjukhus',
#  'Skaraborgs Sjukhus Skövde',
#  'Hallands sjukhus Varberg']

# %% [markdown]
# This list of hospitals does not contain the peculiar entries from before anymore.

# %% [markdown]
# In order to be able to assign a hospital to a BC or Melanoma region later, we need to find out what city a hospital given in `top_account_name` is located in.
# So, we now create a dictionary that maps each hospital given in the above list to its respective address. The addresses have been looked up by hand on Google Maps (21/02/22, 12:00-13:00).

# %%
# These addresses were looked up by hand on Google Maps - 21.02.2022, 12:00-13:00 
address_dict = {'Södra Älvsborgs Sjukhus Borås': 'Brämhultsvägen 53, 501 82 Borås, Schweden',
                'Akademiska sjukhuset': 'Sjukhusvägen, 751 85 Uppsala, Schweden',
                'Drottningmottagningen': 'Drottninggatan 68, 111 21 Stockholm, Schweden',
                'Universitetssjukhuset Linköping': 'Universitetssjukhuset, 581 85 Linköping, Schweden',
                'Hallands sjukhus Halmstad': 'Lasarettsvägen, 302 33 Halmstad, Schweden',
                'Lunds Universitet': 'Lund, Schweden',
                'Mälarsjukhuset': 'Kungsvägen 42, 633 49 Eskilstuna, Schweden',
                'Skellefteå Lasarett': 'Lasarettsvägen 29, 931 41 Skellefteå, Schweden',
                'Universitetssjukhuset Örebro': 'Södra Grev Rosengatan, 701 85 Örebro, Schweden',
                'Capio S:t Görans Sjukhus AB': 'Sankt Göransplan 1, 112 19 Stockholm, Schweden',
                'Blekingesjukhuset i Karlskrona': 'Lasarettsvägen, 371 41 Karlskrona, Schweden',
                'Södersjukhuset': 'Sjukhusbacken 10, 118 83 Stockholm, Schweden',
                'Uddevalla sjukhus': 'Fjällvägen 9, 451 53 Uddevalla, Schweden',
                'Länssjh Sundsvall-Härnösand': 'Lasarettsvägen 21, 856 43 Sundsvall, Schweden',
                'Sophiahemmet AB': 'Valhallavägen 91, 114 86 Stockholm, Schweden',
                'Norrlands Universitetssjukhus': 'Daniel Naezéns väg, 907 37 Umeå, Schweden',
                'Sahlgrenska Univ sjh': 'Blå stråket 5, 413 45 Göteborg, Schweden',
                'Skånes Universitetssjukhus Malmö': 'Carl-Bertil Laurells gata 9, 214 28 Malmö, Schweden',
                'Västmanlands sjukhus Västerås': 'Sigtunagatan, 721 89 Västerås, Schweden',
                'Länssjukhuset i Kalmar': 'Lasarettsvägen 8, 392 44 Kalmar, Schweden',
                'Skånes Universitetssjukhus Lund': 'Entrégatan 7, 222 42 Lund, Schweden',
                'Karolinska Univ Sjh Solna': 'Eugeniavägen 3, 171 64 Solna, Schweden',
                'Visby lasarett': 'S:t Göransgatan 5, 621 55 Visby, Schweden',
                'Länssjukhuset Ryhov': 'Sjukhusgatan, 553 05 Jönköping, Schweden',
                'Gävle Sjukhus': 'Lasarettsvägen 5, 803 24 Gävle, Schweden',
                'Centralsjukhuset i Karlstad': 'Rosenborgsgatan 9, 652 30 Karlstad, Schweden',
                'Centrallasarettet Växjö': 'Strandvägen 8, 352 34 Växjö, Schweden',
                'Falu Lasarett': 'Lasarettsvägen 10, 791 82 Falun, Schweden',
                'Skaraborgs Sjh Lidköping': 'Mellbygatan 11, 531 51 Lidköping, Schweden',
                'Helsingborgs lasarett': 'Charlotte Yhlens gata 10, 252 23 Helsingborg, Schweden',
                'Östersunds Sjukhus': 'Kyrkgatan 16, 831 31 Östersund, Schweden',
                'Skaraborgs Sjukhus Skövde': 'Lövängsvägen, 541 42 Skövde, Schweden',
                'Hallands sjukhus Varberg': 'Träslövsvägen 68, 432 37 Varberg, Schweden'
}

# %%
targets
# Out:
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
# [229 rows x 10 columns]

# %% [markdown]
# We now add a new column `address` with the addresses from `address_dict`.

# %%
targets["address"] = targets["top_account_name"].apply(lambda x: address_dict.get(x))

# %%
targets
# Out:
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id  \
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
#                                                address
# 0            Brämhultsvägen 53, 501 82 Borås, Schweden
# 1               Sjukhusvägen, 751 85 Uppsala, Schweden
# 2        Drottninggatan 68, 111 21 Stockholm, Schweden
# 3    Universitetssjukhuset, 581 85 Linköping, Schweden
# 4            Lasarettsvägen, 302 33 Halmstad, Schweden
# ..                                                 ...
# 224          Daniel Naezéns väg, 907 37 Umeå, Schweden
# 225           Sjukhusgatan, 553 05 Jönköping, Schweden
# 226              Strandvägen 8, 352 34 Växjö, Schweden
# 227           Sjukhusgatan, 553 05 Jönköping, Schweden
# 228     Södra Grev Rosengatan, 701 85 Örebro, Schweden
#
# [229 rows x 11 columns]

# %% [markdown]
# There is both Lunds Universitet and Skånes Universitetssjukhus Lund in the data. Let us take a closer look which HCP belong where.

# %%
targets[targets['top_account_name'] == 'Lunds Universitet']
# Out:
#           account_name account_record_type account_type primary_specialty  \
# 5     Ana Bosch Campos                 HCP       Doctor       SE-99-Övrig
# 217  Olof Bjarnadottir                 HCP       Doctor    SE-42-Onkologi
#
#                  primary_parent_name   top_account_name indication tier  \
# 5    Sekt V Onkologi och patologi MV  Lunds Universitet         BC   T2
# 217                              nan  Lunds Universitet         BC   T3
#
#     segment       account_id         address
# 5        S2  0012o00002kTn92  Lund, Schweden
# 217      S3  0012o00002iER0W  Lund, Schweden

# %%
targets[targets['top_account_name'] == 'Skånes Universitetssjukhus Lund']
# Out:
#                     account_name account_record_type account_type  \
# 27   Christina Haapaniemi Olsson                 HCP       Doctor
# 43            Fredrika Killander                 HCP       Doctor
# 73                  Lars Norberg                 HCP       Doctor
# 83                Maria Svensson                 HCP       Doctor
# 84                Marie Klintman                 HCP       Doctor
# 101                Per Malmström                 HCP       Doctor
# 102         Kala Hatti Önnerfält                 HCP        Nurse
# 103           Anna-Karin Åkesson                 HCP        Nurse
# 126              Helene Almström                 HCP        Nurse
# 155      Kristin Sigurjonsdottir                 HCP       Doctor
# 194                  Malin Ståhl                 HCP        Nurse
# 195                    Lena Berg                 HCP        Nurse
# 196              Camilla Persson                 HCP        Nurse
# 211                   Lisa Rydén                 HCP       Doctor
# 214                 Niklas Loman                 HCP       Doctor
# 219                 Sara Kinhult                 HCP       Doctor
# 220                 Sara Kinhult                 HCP       Doctor
#
#                primary_specialty                     primary_parent_name  \
# 27                SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 43                SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 73                SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 83                SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 84                SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 101               SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 102               SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 103               SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 126  SE-1Y-Gynekologisk onkologi            Allmänna onkologmottagningen
# 155               SE-42-Onkologi              Onkologimottagning 1 och 4
# 194               SE-42-Onkologi              Onkologimottagning 1 och 4
# 195               SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 196               SE-42-Onkologi                         Avd 86 Onkologi
# 211                SE-11-Kirurgi                     Kirurgiska kliniken
# 214               SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 219               SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
# 220               SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
#
#                     top_account_name indication tier segment       account_id  \
# 27   Skånes Universitetssjukhus Lund         BC   T3      S3  0012o00002kTBTj
# 43   Skånes Universitetssjukhus Lund         BC   T2      S2  0012o00002iEVtE
# 73   Skånes Universitetssjukhus Lund         BC   T3      S3  0012o00002kTA2x
# 83   Skånes Universitetssjukhus Lund         BC   T3      S3  0012o00002iEWge
# 84   Skånes Universitetssjukhus Lund         BC   T3      S3  0012o00002kTlCj
# 101  Skånes Universitetssjukhus Lund         BC   T3      S3  0012o00002iERGt
# 102  Skånes Universitetssjukhus Lund         BC   T4      S4  0012o00002iEPkj
# 103  Skånes Universitetssjukhus Lund         BC   NT      S4  0012o00002iEPIp
# 126  Skånes Universitetssjukhus Lund         BC   T4      S4  0012o00002iESbx
# 155  Skånes Universitetssjukhus Lund   Melanoma   T3      S3  0012o00002iDmiB
# 194  Skånes Universitetssjukhus Lund   Melanoma   T1      S4  0012o00002kToYF
# 195  Skånes Universitetssjukhus Lund   Melanoma   T1      S4  0012o00002iEKOI
# 196  Skånes Universitetssjukhus Lund   Melanoma   T3      S4  0012o00002iDsAr
# 211  Skånes Universitetssjukhus Lund         BC   T2      S2  0012o00002iERvB
# 214  Skånes Universitetssjukhus Lund         BC   T1      S1  0012o00002iEUmg
# 219  Skånes Universitetssjukhus Lund         BC   T3      S3  0012o00002iEcCc
# 220  Skånes Universitetssjukhus Lund   Melanoma   T2      S2  0012o00002iEcCc
#
#                                  address
# 27   Entrégatan 7, 222 42 Lund, Schweden
# 43   Entrégatan 7, 222 42 Lund, Schweden
# 73   Entrégatan 7, 222 42 Lund, Schweden
# 83   Entrégatan 7, 222 42 Lund, Schweden
# 84   Entrégatan 7, 222 42 Lund, Schweden
# 101  Entrégatan 7, 222 42 Lund, Schweden
# 102  Entrégatan 7, 222 42 Lund, Schweden
# 103  Entrégatan 7, 222 42 Lund, Schweden
# 126  Entrégatan 7, 222 42 Lund, Schweden
# 155  Entrégatan 7, 222 42 Lund, Schweden
# 194  Entrégatan 7, 222 42 Lund, Schweden
# 195  Entrégatan 7, 222 42 Lund, Schweden
# 196  Entrégatan 7, 222 42 Lund, Schweden
# 211  Entrégatan 7, 222 42 Lund, Schweden
# 214  Entrégatan 7, 222 42 Lund, Schweden
# 219  Entrégatan 7, 222 42 Lund, Schweden
# 220  Entrégatan 7, 222 42 Lund, Schweden

# %%
targets
# Out:
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id  \
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
#                                                address
# 0            Brämhultsvägen 53, 501 82 Borås, Schweden
# 1               Sjukhusvägen, 751 85 Uppsala, Schweden
# 2        Drottninggatan 68, 111 21 Stockholm, Schweden
# 3    Universitetssjukhuset, 581 85 Linköping, Schweden
# 4            Lasarettsvägen, 302 33 Halmstad, Schweden
# ..                                                 ...
# 224          Daniel Naezéns väg, 907 37 Umeå, Schweden
# 225           Sjukhusgatan, 553 05 Jönköping, Schweden
# 226              Strandvägen 8, 352 34 Växjö, Schweden
# 227           Sjukhusgatan, 553 05 Jönköping, Schweden
# 228     Södra Grev Rosengatan, 701 85 Örebro, Schweden
#
# [229 rows x 11 columns]

# %% [markdown]
# ### Add `locality`, `municipality`, `territory`

# %% [markdown]
# We create a new column `locality` that contains the city an HCP belongs to.

# %%
for i in range(len(targets)):
    targets.at[i, 'locality'] = targets.at[i, 'address'].split(', ')[-2].split(' ')[-1]

# %%
targets
# Out:
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id  \
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
#                                                address   locality
# 0            Brämhultsvägen 53, 501 82 Borås, Schweden      Borås
# 1               Sjukhusvägen, 751 85 Uppsala, Schweden    Uppsala
# 2        Drottninggatan 68, 111 21 Stockholm, Schweden  Stockholm
# 3    Universitetssjukhuset, 581 85 Linköping, Schweden  Linköping
# 4            Lasarettsvägen, 302 33 Halmstad, Schweden   Halmstad
# ..                                                 ...        ...
# 224          Daniel Naezéns väg, 907 37 Umeå, Schweden       Umeå
# 225           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 226              Strandvägen 8, 352 34 Växjö, Schweden      Växjö
# 227           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 228     Södra Grev Rosengatan, 701 85 Örebro, Schweden     Örebro
#
# [229 rows x 12 columns]

# %% [markdown]
# In order to get the variable `municipality` - which unfortunately is not always identical to the brick - we merge `targets_subset` with `svenska_stader`.

# %%
svenska_stader
# Out:
#           locality municipality
# 0          Abbekås       Skurup
# 1     Abborrberget    Strängnäs
# 2          Alberga   Eskilstuna
# 3             Alby         Ånge
# 4            Alfta     Ovanåker
# ...            ...          ...
# 1911    Övertorneå   Övertorneå
# 1912    Övertänger         Falu
# 1913        Överum    Västervik
# 1914       Öxabäck         Mark
# 1915        Öxeryd        Lerum
#
# [1916 rows x 2 columns]

# %%
# Merge with 'svenska_stader'
targets = pd.merge(
    targets, 
    svenska_stader, 
    on = 'locality',  
    how = 'left'
)
targets
# Out:
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id  \
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
#                                                address   locality municipality
# 0            Brämhultsvägen 53, 501 82 Borås, Schweden      Borås        Borås
# 1               Sjukhusvägen, 751 85 Uppsala, Schweden    Uppsala      Uppsala
# 2        Drottninggatan 68, 111 21 Stockholm, Schweden  Stockholm    Stockholm
# 3    Universitetssjukhuset, 581 85 Linköping, Schweden  Linköping    Linköping
# 4            Lasarettsvägen, 302 33 Halmstad, Schweden   Halmstad     Halmstad
# ..                                                 ...        ...          ...
# 224          Daniel Naezéns väg, 907 37 Umeå, Schweden       Umeå         Umeå
# 225           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping    Jönköping
# 226              Strandvägen 8, 352 34 Växjö, Schweden      Växjö        Växjö
# 227           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping    Jönköping
# 228     Södra Grev Rosengatan, 701 85 Örebro, Schweden     Örebro       Örebro
#
# [229 rows x 13 columns]

# %% [markdown]
# When looking at the values of `municipality` in `targets_subset` and comparing it to the values of `brick` in `mapping`, some things are striking:
#
# * Solna (a suburb of Stockholm) has no mapped municipality
# * It turns out that Solna is part of Solna Municipality
# * The city of Solna is part of the Stockholm urban area
#
#
# * The locality of Visby is assigned to the municipality of Gotland but in mapping, Visby is a brick of its own. Therefore, change the municipality of Visby from Gotland to Visby.
# * The locality of Göteborg is assigned to the municipality of Göteborg but in mapping, Göteborg is split into several bricks. Therefore, change the municipality of Göteborg from Göteborg to e.g. 'Göteborg-Centrum + V'.
# * The locality of Kalmar is assigned to the municipality of Kalmar but in mapping, Kalmar appears as part of Kalmar/Nybro. Therefore, change the municipality of Kalmar from Kalmar to Kalmar/Nybro.
# * The locality of Solna is not present in svenska_stader. As Solna is part of the Stockholm urban area, assign the locality Solna to e.g the municipality of 'Stockholm-NO'.
# * The locality of Stockholm is assigned to the municipality of Stockholm but in mapping, Stockholm is split into several bricks. Therefore, change the municipality of Stockholm from Stockholm to e.g. 'Stockholm-NO'.
# * The locality of Lidköping is assigned to the municipality of Lidköping but in mapping, Lidköping appears as part of Lidköping/Skara. Therefore, change the municipality of Lidköping from Lidköping to Lidköping/Skara.
# * The locality of Helsingborg is assigned to the municipality of Helsingborg but in mapping, Helsingborg appears as part of Helsingborg/Landskrona. Therefore, change the municipality of Helsingborg from Helsingborg to Helsingborg/Landskrona.
#
# * The locality of Falun is assigned to the municipality of Falu but in mapping, Falu appears as part of Borlänge/Falun. Therefore, change the municipality of Falu from Falu to Borlänge/Falun.
# * The locality of Varberg is assigned to the municipality of Varberg but in mapping, Varberg appears as part of Falkenberg/Varberg. Therefore, change the municipality of Varberg from Varberg to Falkenberg/Varberg.

# %%
for i in range(len(targets)):
    if targets.at[i, 'locality'] == 'Solna': 
        targets.at[i, 'municipality'] = 'Stockholm-NO' 
targets['municipality'] = targets['municipality'].replace('Gotland', 'Visby')
targets['municipality'] = targets['municipality'].replace('Göteborg', 'Göteborg-Centrum + V')
targets['municipality'] = targets['municipality'].replace('Kalmar', 'Kalmar/Nybro')
targets['municipality'] = targets['municipality'].replace('Stockholm', 'Stockholm-NO')
targets['municipality'] = targets['municipality'].replace('Lidköping', 'Lidköping/Skara')
targets['municipality'] = targets['municipality'].replace('Helsingborg', 'Helsingborg/Landskrona')
targets['municipality'] = targets['municipality'].replace('Falu', 'Borlänge/Falun')
targets['municipality'] = targets['municipality'].replace('Varberg', 'Falkenberg/Varberg')

# %%
targets
# Out:
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id  \
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
#                                                address   locality  \
# 0            Brämhultsvägen 53, 501 82 Borås, Schweden      Borås
# 1               Sjukhusvägen, 751 85 Uppsala, Schweden    Uppsala
# 2        Drottninggatan 68, 111 21 Stockholm, Schweden  Stockholm
# 3    Universitetssjukhuset, 581 85 Linköping, Schweden  Linköping
# 4            Lasarettsvägen, 302 33 Halmstad, Schweden   Halmstad
# ..                                                 ...        ...
# 224          Daniel Naezéns väg, 907 37 Umeå, Schweden       Umeå
# 225           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 226              Strandvägen 8, 352 34 Växjö, Schweden      Växjö
# 227           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 228     Södra Grev Rosengatan, 701 85 Örebro, Schweden     Örebro
#
#      municipality
# 0           Borås
# 1         Uppsala
# 2    Stockholm-NO
# 3       Linköping
# 4        Halmstad
# ..            ...
# 224          Umeå
# 225     Jönköping
# 226         Växjö
# 227     Jönköping
# 228        Örebro
#
# [229 rows x 13 columns]

# %% [markdown]
# We now the variable `territory`.

# %%
mapping
# Out:
#                 brick                 sweden_bc                      sweden_me
# 0        02 Norrtälje                 Stockholm                 Stockholm ONCO
# 1          04 Uppsala                   Uppsala                   Uppsala ONCO
# 2         03 Enköping                   Uppsala                   Uppsala ONCO
# 3         05 Nyköping       Sörmland-Eskilstuna       Sörmland-Eskilstuna ONCO
# 4      06 Katrineholm       Sörmland-Eskilstuna       Sörmland-Eskilstuna ONCO
# ..                ...                       ...                            ...
# 73         85 Kungälv  Västra Götaland-Göteborg  Västra Götaland-Göteborg ONCO
# 74  86 Lerum/Alingsås  Västra Götaland-Alingsås       Västra Götaland-SÄS ONCO
# 75           91 Malmö                Skåne-Lund                     Skåne ONCO
# 76            92 Lund                Skåne-Lund                     Skåne ONCO
# 77      93 Trelleborg                Skåne-Lund                     Skåne ONCO
#
# [78 rows x 3 columns]

# %% [markdown]
# In order to be able to merge `mapping` to `targets_subset`, we need to ensure that the `brick` variable in `mapping` and the `municipality` variable in `targets_subset` have the same format, i.e., the two digits at the start of any entry in `brick` must be removed.

# %%
mapping['brick'] = mapping['brick'].astype(str)
for i in range(len(mapping)):
    brick_split_list = mapping['brick'][i].split(' ')[1:]
    mapping.at[i, 'brick'] = ' '.join(brick_split_list)
mapping
# Out:
#              brick                 sweden_bc                      sweden_me
# 0        Norrtälje                 Stockholm                 Stockholm ONCO
# 1          Uppsala                   Uppsala                   Uppsala ONCO
# 2         Enköping                   Uppsala                   Uppsala ONCO
# 3         Nyköping       Sörmland-Eskilstuna       Sörmland-Eskilstuna ONCO
# 4      Katrineholm       Sörmland-Eskilstuna       Sörmland-Eskilstuna ONCO
# ..             ...                       ...                            ...
# 73         Kungälv  Västra Götaland-Göteborg  Västra Götaland-Göteborg ONCO
# 74  Lerum/Alingsås  Västra Götaland-Alingsås       Västra Götaland-SÄS ONCO
# 75           Malmö                Skåne-Lund                     Skåne ONCO
# 76            Lund                Skåne-Lund                     Skåne ONCO
# 77      Trelleborg                Skåne-Lund                     Skåne ONCO
#
# [78 rows x 3 columns]

# %%
# add territory

for i in range(len(targets)):
    municipality = targets['municipality'][i]
    #territory = ''
    index = mapping[mapping['brick'] == municipality].index[0]
    if targets['indication'][i] == 'BC':
        territory = mapping.loc[index, 'sweden_bc']
    elif targets['indication'][i] == 'Melanoma':
        territory = mapping.loc[index, 'sweden_me']
    
    #print(i, territory)
    targets.at[i, 'territory'] = territory
targets
# Out:
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id  \
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
#                                                address   locality  \
# 0            Brämhultsvägen 53, 501 82 Borås, Schweden      Borås
# 1               Sjukhusvägen, 751 85 Uppsala, Schweden    Uppsala
# 2        Drottninggatan 68, 111 21 Stockholm, Schweden  Stockholm
# 3    Universitetssjukhuset, 581 85 Linköping, Schweden  Linköping
# 4            Lasarettsvägen, 302 33 Halmstad, Schweden   Halmstad
# ..                                                 ...        ...
# 224          Daniel Naezéns väg, 907 37 Umeå, Schweden       Umeå
# 225           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 226              Strandvägen 8, 352 34 Växjö, Schweden      Växjö
# 227           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 228     Södra Grev Rosengatan, 701 85 Örebro, Schweden     Örebro
#
#      municipality               territory
# 0           Borås   Västra Götaland-Borås
# 1         Uppsala                 Uppsala
# 2    Stockholm-NO               Stockholm
# 3       Linköping  Östergötland-Linköping
# 4        Halmstad        Halland-Halmstad
# ..            ...                     ...
# 224          Umeå  Västerbotten-Umeå ONCO
# 225     Jönköping     Jönköping-Jönköping
# 226         Växjö    Kronoberg-Växjö ONCO
# 227     Jönköping          Jönköping ONCO
# 228        Örebro      Örebro-Örebro ONCO
#
# [229 rows x 14 columns]

# %% [markdown]
# ### `tier`

# %% [markdown]
# Hildur Helgadottir has no value for `tier`.
#
# She is in S1, so let us take a look what tier other HCPs are in S1.

# %%
targets[targets['segment'] == 'S1']
# Out:
#                 account_name account_record_type account_type  \
# 13         Anna-Karin Tzikas                 HCP       Doctor
# 16   Anne-Kristine Andersson                 HCP       Doctor
# 17         Antonios Valachis                 HCP       Doctor
# 19         Barbro Linderholm                 HCP       Doctor
# 53            Henrik Lindman                 HCP       Doctor
# 56               Jan Frisell                 HCP       Doctor
# 59             Johan Hartman                 HCP       Doctor
# 60               Jonas Bergh                 HCP       Doctor
# 80              Maria Ekholm                 HCP       Doctor
# 100             Per Karlsson                 HCP       Doctor
# 113              Ulrik Narbe                 HCP       Doctor
# 117         Irma Fredriksson                 HCP       Doctor
# 127       Hildur Helgadottir                 HCP       Doctor
# 129          Gustav Ullenhag                 HCP       Doctor
# 208                  Lars Ny                 HCP       Doctor
# 214             Niklas Loman                 HCP       Doctor
#
#           primary_specialty                     primary_parent_name  \
# 13           SE-42-Onkologi                          Onkologenheten
# 16           SE-42-Onkologi                           Cancercentrum
# 17           SE-42-Onkologi                    Onkologiska kliniken
# 19           SE-42-Onkologi                             VO Onkologi
# 53           SE-42-Onkologi                         Onkologkliniken
# 56            SE-11-Kirurgi                            Bröstcentrum
# 59   SE-03-Klinisk patologi  ME Klinisk patologi och cytologi Solna
# 60           SE-42-Onkologi                            Bröstcentrum
# 80           SE-42-Onkologi                         Onkologkliniken
# 100          SE-42-Onkologi        Per Karlsson Oncology Consulting
# 113          SE-42-Onkologi                         Onkologkliniken
# 117           SE-11-Kirurgi                            Bröstcentrum
# 127          SE-42-Onkologi     ME Huvud- hals- lung- och hudcancer
# 129          SE-42-Onkologi                         Onkologkliniken
# 208          SE-42-Onkologi                             VO Onkologi
# 214          SE-42-Onkologi  VO Hematologi Onkologi Strålningsfysik
#
#                     top_account_name indication tier segment       account_id  \
# 13                 Uddevalla sjukhus         BC   T1      S1  0012o00002iEd8I
# 16     Norrlands Universitetssjukhus         BC   T1      S1  0012o00002iETyo
# 17      Universitetssjukhuset Örebro         BC   T1      S1  0012o00002iEVfq
# 19              Sahlgrenska Univ sjh         BC   T1      S1  0012o00002iETcV
# 53              Akademiska sjukhuset         BC   T1      S1  0012o00002kTAh5
# 56         Karolinska Univ Sjh Solna         BC   T1      S1  0012o00002kTE4Y
# 59         Karolinska Univ Sjh Solna         BC   T1      S1  0012o00002iEVWw
# 60         Karolinska Univ Sjh Solna         BC   T1      S1  0012o00002iEfZT
# 80               Länssjukhuset Ryhov         BC   T1      S1  0012o00002iEezE
# 100             Sahlgrenska Univ sjh         BC   T1      S1  0012o00002kTDQh
# 113          Centrallasarettet Växjö         BC   T1      S1  0012o00002iET38
# 117        Karolinska Univ Sjh Solna         BC   T1      S1  0012o00002iEU48
# 127        Karolinska Univ Sjh Solna   Melanoma  NaN      S1  0012o00002iESmB
# 129             Akademiska sjukhuset   Melanoma   ST      S1  0012o00002kTBYO
# 208             Sahlgrenska Univ sjh   Melanoma   ST      S1  0012o00002iEPVv
# 214  Skånes Universitetssjukhus Lund         BC   T1      S1  0012o00002iEUmg
#
#                                             address   locality  \
# 13         Fjällvägen 9, 451 53 Uddevalla, Schweden  Uddevalla
# 16        Daniel Naezéns väg, 907 37 Umeå, Schweden       Umeå
# 17   Södra Grev Rosengatan, 701 85 Örebro, Schweden     Örebro
# 19         Blå stråket 5, 413 45 Göteborg, Schweden   Göteborg
# 53           Sjukhusvägen, 751 85 Uppsala, Schweden    Uppsala
# 56           Eugeniavägen 3, 171 64 Solna, Schweden      Solna
# 59           Eugeniavägen 3, 171 64 Solna, Schweden      Solna
# 60           Eugeniavägen 3, 171 64 Solna, Schweden      Solna
# 80         Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 100        Blå stråket 5, 413 45 Göteborg, Schweden   Göteborg
# 113           Strandvägen 8, 352 34 Växjö, Schweden      Växjö
# 117          Eugeniavägen 3, 171 64 Solna, Schweden      Solna
# 127          Eugeniavägen 3, 171 64 Solna, Schweden      Solna
# 129          Sjukhusvägen, 751 85 Uppsala, Schweden    Uppsala
# 208        Blå stråket 5, 413 45 Göteborg, Schweden   Göteborg
# 214             Entrégatan 7, 222 42 Lund, Schweden       Lund
#
#              municipality                      territory
# 13              Uddevalla      Västra Götaland-Uddevalla
# 16                   Umeå              Västerbotten-Umeå
# 17                 Örebro                  Örebro-Örebro
# 19   Göteborg-Centrum + V       Västra Götaland-Göteborg
# 53                Uppsala                        Uppsala
# 56           Stockholm-NO                      Stockholm
# 59           Stockholm-NO                      Stockholm
# 60           Stockholm-NO                      Stockholm
# 80              Jönköping            Jönköping-Jönköping
# 100  Göteborg-Centrum + V       Västra Götaland-Göteborg
# 113                 Växjö                Kronoberg-Växjö
# 117          Stockholm-NO                      Stockholm
# 127          Stockholm-NO                 Stockholm ONCO
# 129               Uppsala                   Uppsala ONCO
# 208  Göteborg-Centrum + V  Västra Götaland-Göteborg ONCO
# 214                  Lund                     Skåne-Lund

# %% [markdown]
# These HCPs are either in T1 or ST. The vast majority is in T1. We now also assign Hildur Helgadottir to T1.

# %%
targets.loc[targets['account_name'] == 'Hildur Helgadottir', ['tier']] = 'T1'
targets
# Out:
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id  \
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
#                                                address   locality  \
# 0            Brämhultsvägen 53, 501 82 Borås, Schweden      Borås
# 1               Sjukhusvägen, 751 85 Uppsala, Schweden    Uppsala
# 2        Drottninggatan 68, 111 21 Stockholm, Schweden  Stockholm
# 3    Universitetssjukhuset, 581 85 Linköping, Schweden  Linköping
# 4            Lasarettsvägen, 302 33 Halmstad, Schweden   Halmstad
# ..                                                 ...        ...
# 224          Daniel Naezéns väg, 907 37 Umeå, Schweden       Umeå
# 225           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 226              Strandvägen 8, 352 34 Växjö, Schweden      Växjö
# 227           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 228     Södra Grev Rosengatan, 701 85 Örebro, Schweden     Örebro
#
#      municipality               territory
# 0           Borås   Västra Götaland-Borås
# 1         Uppsala                 Uppsala
# 2    Stockholm-NO               Stockholm
# 3       Linköping  Östergötland-Linköping
# 4        Halmstad        Halland-Halmstad
# ..            ...                     ...
# 224          Umeå  Västerbotten-Umeå ONCO
# 225     Jönköping     Jönköping-Jönköping
# 226         Växjö    Kronoberg-Växjö ONCO
# 227     Jönköping          Jönköping ONCO
# 228        Örebro      Örebro-Örebro ONCO
#
# [229 rows x 14 columns]

# %%
targets
# Out:
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id  \
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
#                                                address   locality  \
# 0            Brämhultsvägen 53, 501 82 Borås, Schweden      Borås
# 1               Sjukhusvägen, 751 85 Uppsala, Schweden    Uppsala
# 2        Drottninggatan 68, 111 21 Stockholm, Schweden  Stockholm
# 3    Universitetssjukhuset, 581 85 Linköping, Schweden  Linköping
# 4            Lasarettsvägen, 302 33 Halmstad, Schweden   Halmstad
# ..                                                 ...        ...
# 224          Daniel Naezéns väg, 907 37 Umeå, Schweden       Umeå
# 225           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 226              Strandvägen 8, 352 34 Växjö, Schweden      Växjö
# 227           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 228     Södra Grev Rosengatan, 701 85 Örebro, Schweden     Örebro
#
#      municipality               territory
# 0           Borås   Västra Götaland-Borås
# 1         Uppsala                 Uppsala
# 2    Stockholm-NO               Stockholm
# 3       Linköping  Östergötland-Linköping
# 4        Halmstad        Halland-Halmstad
# ..            ...                     ...
# 224          Umeå  Västerbotten-Umeå ONCO
# 225     Jönköping     Jönköping-Jönköping
# 226         Växjö    Kronoberg-Växjö ONCO
# 227     Jönköping          Jönköping ONCO
# 228        Örebro      Örebro-Örebro ONCO
#
# [229 rows x 14 columns]

# %%
# Save the prepared data frame
route0 = "../processed_data"

if not os.path.exists(route0):
    os.mkdir(route0)
    
print("saving file corresponding to targets.pkl")
targets.to_pickle(f"{route0}/targets.pkl")
pd.read_pickle(f"{route0}/targets.pkl")
# Out:
# saving file corresponding to targets.pkl
#                 account_name account_record_type account_type  \
# 0        Adel Bader Hamdalla                 HCP       Doctor
# 1              Aglaia Schiza                 HCP       Doctor
# 2      Agneta Nordin Danfors                 HCP       Doctor
# 3    Ahmed Abbas Albu-Kareem                 HCP       Doctor
# 4                Alaa Haidar                 HCP       Doctor
# ..                       ...                 ...          ...
# 224   Ylva Holmgren Stenlund                 HCP       Doctor
# 225              Anna Nyberg                 HCP       Doctor
# 226          Göran Carlstedt                 HCP       Doctor
# 227         Mikael Wallander                 HCP       Doctor
# 228          Frida Jakobsson                 HCP       Doctor
#
#        primary_specialty          primary_parent_name  \
# 0         SE-42-Onkologi  Avd E71 Hematologi onkologi
# 1         SE-42-Onkologi              Onkologkliniken
# 2    SE-1J-Bröstonkologi        Drottningmottagningen
# 3         SE-42-Onkologi         Onkologiska kliniken
# 4         SE-42-Onkologi          Onkologiska enheten
# ..                   ...                          ...
# 224       SE-42-Onkologi                Cancercentrum
# 225       SE-42-Onkologi              Onkologkliniken
# 226       SE-42-Onkologi              Onkologkliniken
# 227       SE-42-Onkologi              Onkologkliniken
# 228       SE-42-Onkologi         Onkologiska kliniken
#
#                     top_account_name indication tier segment       account_id  \
# 0      Södra Älvsborgs Sjukhus Borås         BC   T3      S3  0012o00002kTDKp
# 1               Akademiska sjukhuset         BC   T3      S3  0012o00002kTBeA
# 2              Drottningmottagningen         BC   T2      S2  0012o00002iEZxE
# 3    Universitetssjukhuset Linköping         BC   T2      S2  0012o00002kTAKC
# 4          Hallands sjukhus Halmstad         BC   T2      S2  0012o00002iDs1j
# ..                               ...        ...  ...     ...              ...
# 224    Norrlands Universitetssjukhus   Melanoma   T2      S3  0012o00002iEaBJ
# 225              Länssjukhuset Ryhov         BC   T3      S3  0012o00002iEYHR
# 226          Centrallasarettet Växjö   Melanoma   T2      S3  0012o00002iETYR
# 227              Länssjukhuset Ryhov   Melanoma   T2      S3  0012o00002kT9l2
# 228     Universitetssjukhuset Örebro   Melanoma   T1      S3  0012o00002iETXT
#
#                                                address   locality  \
# 0            Brämhultsvägen 53, 501 82 Borås, Schweden      Borås
# 1               Sjukhusvägen, 751 85 Uppsala, Schweden    Uppsala
# 2        Drottninggatan 68, 111 21 Stockholm, Schweden  Stockholm
# 3    Universitetssjukhuset, 581 85 Linköping, Schweden  Linköping
# 4            Lasarettsvägen, 302 33 Halmstad, Schweden   Halmstad
# ..                                                 ...        ...
# 224          Daniel Naezéns väg, 907 37 Umeå, Schweden       Umeå
# 225           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 226              Strandvägen 8, 352 34 Växjö, Schweden      Växjö
# 227           Sjukhusgatan, 553 05 Jönköping, Schweden  Jönköping
# 228     Södra Grev Rosengatan, 701 85 Örebro, Schweden     Örebro
#
#      municipality               territory
# 0           Borås   Västra Götaland-Borås
# 1         Uppsala                 Uppsala
# 2    Stockholm-NO               Stockholm
# 3       Linköping  Östergötland-Linköping
# 4        Halmstad        Halland-Halmstad
# ..            ...                     ...
# 224          Umeå  Västerbotten-Umeå ONCO
# 225     Jönköping     Jönköping-Jönköping
# 226         Växjö    Kronoberg-Växjö ONCO
# 227     Jönköping          Jönköping ONCO
# 228        Örebro      Örebro-Örebro ONCO
#
# [229 rows x 14 columns]
