# %% [markdown]
# # Aggregation of population by region
#
# In this notebook, we create a new dataset `population_by_region.pkl` from the two datasets `mapping.pkl` and `population_by_brick.pkl`. This new dataset gives us the population in 2022 for all BC and melanoma regions.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os

#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Define helper function

# %%
def aggregate_population_by_region(data, column):
    """
    Aggregate the population per brick for each cancer region.
    """
    # Group and sum by 'sweden_bc'
    data_bc = data.groupby(by = 'sweden_bc').sum().reset_index()
    # Rename 'sweden_bc' to 'territory'
    data_bc = data_bc.rename(columns = {"sweden_bc": column})

    # Group and sum by 'sweden_me'
    data_me = data.groupby(by = 'sweden_me').sum().reset_index()
    # Rename 'sweden_me' to 'territory'
    data_me = data_me.rename(columns = {"sweden_me": column})

    # Concatenate data_bc and data_me
    data = pd.concat([data_bc, data_me], ignore_index = True)
    
    return(data)

# %% [markdown]
# ## Load data

# %%
mapping = pd.read_pickle("../processed_data/mapping.pkl")
population_by_brick = pd.read_pickle("../processed_data/population_by_brick.pkl")

# %%
mapping
# Out:
#                 brick                 sweden_bc                      sweden_me
# 0        02 Norrtälje                 Stockholm                 Stockholm ONCO
# 1          04 Uppsala                   Uppsala                   Uppsala ONCO
# 2         03 Enköping                   Uppsala                   Uppsala ONCO
# 3         05 Nyköping       Sörmland-Eskilstuna       Sörmland-Eskilstuna ONCO
# 4      06 Katrineholm       Sörmland-Eskilstuna       Sörmland-Eskilstuna ONCO
# ..                ...                       ...                            ...
# 73         85 Kungälv  Västra Götaland-Göteborg  Västra Götaland-Göteborg ONCO
# 74  86 Lerum/Alingsås  Västra Götaland-Alingsås       Västra Götaland-SÄS ONCO
# 75           91 Malmö                Skåne-Lund                     Skåne ONCO
# 76            92 Lund                Skåne-Lund                     Skåne ONCO
# 77      93 Trelleborg                Skåne-Lund                     Skåne ONCO
#
# [78 rows x 3 columns]

# %%
population_by_brick
# Out:
#               brick  population
# 0    73 Stockholm-V    457418.0
# 1   72 Stockholm-NV    404184.0
# 2    75 Stockholm-S    641403.0
# 3   76 Stockholm-SV    414460.0
# 4   71 Stockholm-NO    281467.0
# ..              ...         ...
# 73       15 Ljungby     38790.0
# 74    22 Karlskrona     96295.0
# 75     23 Karlshamn     63256.0
# 76     63 Östersund    130191.0
# 77         21 Visby     59191.0
#
# [78 rows x 2 columns]

# %% [markdown]
# ## Aggregation steps

# %%
# Merge mapping and population_by_brick
population_bc_me = pd.merge(
    mapping, 
    population_by_brick, 
    on = 'brick',  
    how = 'left'
)

population_bc_me
# Out:
#                 brick                 sweden_bc  \
# 0        02 Norrtälje                 Stockholm
# 1          04 Uppsala                   Uppsala
# 2         03 Enköping                   Uppsala
# 3         05 Nyköping       Sörmland-Eskilstuna
# 4      06 Katrineholm       Sörmland-Eskilstuna
# ..                ...                       ...
# 73         85 Kungälv  Västra Götaland-Göteborg
# 74  86 Lerum/Alingsås  Västra Götaland-Alingsås
# 75           91 Malmö                Skåne-Lund
# 76            92 Lund                Skåne-Lund
# 77      93 Trelleborg                Skåne-Lund
#
#                         sweden_me  population
# 0                  Stockholm ONCO     61689.0
# 1                    Uppsala ONCO    287170.0
# 2                    Uppsala ONCO     58281.0
# 3        Sörmland-Eskilstuna ONCO     92517.0
# 4        Sörmland-Eskilstuna ONCO     60313.0
# ..                            ...         ...
# 73  Västra Götaland-Göteborg ONCO     88901.0
# 74       Västra Götaland-SÄS ONCO    125696.0
# 75                     Skåne ONCO    338230.0
# 76                     Skåne ONCO    222013.0
# 77                     Skåne ONCO    102877.0
#
# [78 rows x 4 columns]

# %%
population_bc_me = aggregate_population_by_region(population_bc_me, 'territory')
population_bc_me
# Out:
#                         territory  population
# 0                        Blekinge    159551.0
# 1                         Dalarna    286928.0
# 2                 Gävleborg-Gävle    130274.0
# 3                Halland-Halmstad    137517.0
# 4      Halland-Varberg-Falkenberg    108276.0
# 5                        Jämtland    130191.0
# 6             Jönköping-Jönköping    198325.0
# 7          Jönköping-Nässjö-Eksjö     88216.0
# 8               Jönköping-Värnamo     74005.0
# 9                          Kalmar    244488.0
# 10              Kronoberg-Ljungby     38790.0
# 11                Kronoberg-Växjö    160878.0
# 12           Norrbotten-Sunderbyn    250336.0
# 13                       SE-other         0.0
# 14   Skåne-Helsingborg-Landskrona    347686.0
# 15             Skåne-Kristianstad    185326.0
# 16                     Skåne-Lund    826726.0
# 17                      Stockholm   2339287.0
# 18              Stockholm-Gotland     59191.0
# 19            Sörmland-Eskilstuna    294317.0
# 20                        Uppsala    531917.0
# 21              Värmland-Karlstad    281269.0
# 22        Västerbotten-Skellefteå     79640.0
# 23              Västerbotten-Umeå    190346.0
# 24       Västernorrland-Sundsvall    189132.0
# 25    Västernorrland-Örnsköldsvik     56053.0
# 26           Västmanland-Västerås    273539.0
# 27       Västra Götaland-Alingsås    125696.0
# 28          Västra Götaland-Borås    219332.0
# 29       Västra Götaland-Göteborg    896297.0
# 30      Västra Götaland-Lidköping    132728.0
# 31         Västra Götaland-Skövde    128905.0
# 32      Västra Götaland-Uddevalla    290816.0
# 33                  Örebro-Örebro    301906.0
# 34         Östergötland-Linköping    275333.0
# 35        Östergötland-Norrköping    185785.0
# 36                  Blekinge ONCO    159551.0
# 37                   Dalarna ONCO    286928.0
# 38           Gävleborg-Gävle ONCO    286268.0
# 39          Halland-Halmstad ONCO    137517.0
# 40                  Jämtland ONCO    130191.0
# 41                 Jönköping ONCO    360546.0
# 42                    Kalmar ONCO    244488.0
# 43           Kronoberg-Växjö ONCO    199668.0
# 44      Norrbotten-Sunderbyn ONCO    250336.0
# 45                  SE-other ONCO         0.0
# 46                     Skåne ONCO   1359738.0
# 47                 Stockholm ONCO   2339287.0
# 48         Stockholm-Gotland ONCO     59191.0
# 49       Sörmland-Eskilstuna ONCO    294317.0
# 50                   Uppsala ONCO    375923.0
# 51         Värmland-Karlstad ONCO    281269.0
# 52         Västerbotten-Umeå ONCO    269986.0
# 53  Västernorrland-Sundsvall ONCO    245185.0
# 54      Västmanland-Västerås ONCO    273539.0
# 55  Västra Götaland-Göteborg ONCO   1295389.0
# 56       Västra Götaland-SÄS ONCO    606661.0
# 57             Örebro-Örebro ONCO    301906.0
# 58    Östergötland-Linköping ONCO    461118.0

# %%
# Save the new dataset
route0 = "../processed_data"

if not os.path.exists(route0):
    os.mkdir(route0)
    
print("saving file corresponding to population_by_region.pkl")
population_bc_me.to_pickle(f"{route0}/population_by_region.pkl")
pd.read_pickle(f"{route0}/population_by_region.pkl")
# Out:
# saving file corresponding to population_by_region.pkl
#                         territory  population
# 0                        Blekinge    159551.0
# 1                         Dalarna    286928.0
# 2                 Gävleborg-Gävle    130274.0
# 3                Halland-Halmstad    137517.0
# 4      Halland-Varberg-Falkenberg    108276.0
# 5                        Jämtland    130191.0
# 6             Jönköping-Jönköping    198325.0
# 7          Jönköping-Nässjö-Eksjö     88216.0
# 8               Jönköping-Värnamo     74005.0
# 9                          Kalmar    244488.0
# 10              Kronoberg-Ljungby     38790.0
# 11                Kronoberg-Växjö    160878.0
# 12           Norrbotten-Sunderbyn    250336.0
# 13                       SE-other         0.0
# 14   Skåne-Helsingborg-Landskrona    347686.0
# 15             Skåne-Kristianstad    185326.0
# 16                     Skåne-Lund    826726.0
# 17                      Stockholm   2339287.0
# 18              Stockholm-Gotland     59191.0
# 19            Sörmland-Eskilstuna    294317.0
# 20                        Uppsala    531917.0
# 21              Värmland-Karlstad    281269.0
# 22        Västerbotten-Skellefteå     79640.0
# 23              Västerbotten-Umeå    190346.0
# 24       Västernorrland-Sundsvall    189132.0
# 25    Västernorrland-Örnsköldsvik     56053.0
# 26           Västmanland-Västerås    273539.0
# 27       Västra Götaland-Alingsås    125696.0
# 28          Västra Götaland-Borås    219332.0
# 29       Västra Götaland-Göteborg    896297.0
# 30      Västra Götaland-Lidköping    132728.0
# 31         Västra Götaland-Skövde    128905.0
# 32      Västra Götaland-Uddevalla    290816.0
# 33                  Örebro-Örebro    301906.0
# 34         Östergötland-Linköping    275333.0
# 35        Östergötland-Norrköping    185785.0
# 36                  Blekinge ONCO    159551.0
# 37                   Dalarna ONCO    286928.0
# 38           Gävleborg-Gävle ONCO    286268.0
# 39          Halland-Halmstad ONCO    137517.0
# 40                  Jämtland ONCO    130191.0
# 41                 Jönköping ONCO    360546.0
# 42                    Kalmar ONCO    244488.0
# 43           Kronoberg-Växjö ONCO    199668.0
# 44      Norrbotten-Sunderbyn ONCO    250336.0
# 45                  SE-other ONCO         0.0
# 46                     Skåne ONCO   1359738.0
# 47                 Stockholm ONCO   2339287.0
# 48         Stockholm-Gotland ONCO     59191.0
# 49       Sörmland-Eskilstuna ONCO    294317.0
# 50                   Uppsala ONCO    375923.0
# 51         Värmland-Karlstad ONCO    281269.0
# 52         Västerbotten-Umeå ONCO    269986.0
# 53  Västernorrland-Sundsvall ONCO    245185.0
# 54      Västmanland-Västerås ONCO    273539.0
# 55  Västra Götaland-Göteborg ONCO   1295389.0
# 56       Västra Götaland-SÄS ONCO    606661.0
# 57             Örebro-Örebro ONCO    301906.0
# 58    Östergötland-Linköping ONCO    461118.0
