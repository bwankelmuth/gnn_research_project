# %% [markdown]
# # Web Scraping of PubMed
#
# In this notebook, we perform web scraping of PubMed using the Python library PyMed. Our primary goal is to scrape papers and co-authors.

# %%
import pandas as pd
import numpy as np

import requests
import time
import itertools

import matplotlib.pyplot as plt
import json
import os

from pymed import PubMed

# %%
# Create results folder
route0 = "../web_scraping_data"

if not os.path.exists(route0):
    os.mkdir(route0)

# %% [markdown]
# ## Load HCPs

# %%
# Load the file with HCP data
hcp_df = pd.read_excel("../novartis_data/BC & Melanoma targets Sweden.xlsx")

# Detect copyrights, it's separated by NA line
ind_cpr = hcp_df.loc[pd.isna(hcp_df["Name"]), :].index[0]

# Remove copyrights and duplicates
hcp_names = pd.Series(hcp_df["Name"].head(ind_cpr).unique())

# %% [markdown]
# ## Querying of PubMed using PyMed

# %%
# Initialization of API object
pubmed = PubMed(tool="MyTool", email="my@email.address")

# %%
start_time = time.time()

n_max = 100

papers_df = []

for i in range(len(hcp_names)): # Level: HCPs
    
    name_i = hcp_names.loc[i]
    query_i = f"{name_i}"
    print(f"{i + 1}/{len(hcp_names)} --- {query_i}")
    
    # Check how many articles there are
    results_i = pubmed.query(query_i, max_results=n_max)
    results_num = len([x for x in results_i])
    
    if results_num > 0:
        results_i = pubmed.query(query_i, max_results=n_max)
    else:
        results_i = []
        
    # Loop over the retrieved articles
    papers_df_i = []
    for article in results_i: # Level: Articles per HCP
        dict_i = json.loads(article.toJSON())

        # Drop unnecessary columns
        if "xml" in dict_i.keys():
            del dict_i["xml"]
        if "doi" in dict_i.keys():
            del dict_i["doi"]

        df_i = pd.DataFrame.from_dict([dict_i])
        df_i["hcp_name"] = name_i
        df_i["num_articles"] = results_num
        
        #extract co-authors
        first_name = []
        last_name = []
        
        for j in dict_i["authors"]:
            first_name.append(j['firstname'])
            last_name.append(j['lastname'])
        names = list(zip(first_name, last_name))
        names = str(names)
        df_i["authors"] = names

        papers_df_i.append(df_i) # this df now contains all the papers of one HCP
        
    if len(papers_df_i) > 0:
        papers_df_i = pd.concat(papers_df_i)
        papers_df.append(papers_df_i)
    else:
        papers_df_i = pd.DataFrame({
            "hcp_name": [name_i],
            "num_articles": [results_num]
        })
        papers_df.append(papers_df_i)
        
    # Store data at the end
    if i == len(hcp_names) - 1:
        print("saving file corresponding to results_queries_pm.csv")
        papers_df = pd.concat(papers_df).reset_index(drop = True)
        papers_df.to_csv(f"{route0}/results_queries_pm.csv", index = False)
        

end_time = time.time()
duration = end_time - start_time
print(f"{int(np.floor(duration/3600))} hours {(duration-3600*np.floor(duration/3600))/60:.4} minutes")
# Out:
# 1/208 --- Adel Bader Hamdalla
# 2/208 --- Aglaia Schiza
# 3/208 --- Agneta Nordin Danfors
# 4/208 --- Ahmed Abbas Albu-Kareem
# 5/208 --- Alaa Haidar
# 6/208 --- Ana Bosch Campos
# 7/208 --- Andreas Nearchou
# 8/208 --- Ulrika Bergqvist
# 9/208 --- Ann Charlotte Dreifaldt
# 10/208 --- Elisabeth Ryd Ausén
# 11/208 --- Marie Santonsson
# 12/208 --- Anna Nordenskjöld
# 13/208 --- Anna von Wachenfeldt Väppling
# 14/208 --- Anna-Karin Tzikas
# 15/208 --- Anna-Karin Wennstig
# 16/208 --- Anna Maria Hasselgren Häll
# 17/208 --- Anne-Kristine Andersson
# 18/208 --- Antonios Valachis
# 19/208 --- Elisabet Karlsson
# 20/208 --- Barbro Linderholm
# 21/208 --- Birgitta Lind
# 22/208 --- Kristina Lindblom
# 23/208 --- Maria Sandström
# 24/208 --- Cecilia Graffman
# 25/208 --- Cecilia Nilsson
# 26/208 --- Chaido Chamalidou
# 27/208 --- Charlotte Bratthäll
# 28/208 --- Christina Haapaniemi Olsson
# 29/208 --- Christina Linder Stragliotto
# 30/208 --- Malin Steenhoff
# 31/208 --- Therése Widerberg
# 32/208 --- Claudia Lundgren
# 33/208 --- Dan Lundstedt
# 34/208 --- Dawid Bulanda
# 35/208 --- Julia Hallerfelt
# 36/208 --- Yohana Collins Bikova
# 37/208 --- Yvonne Wengström
# 38/208 --- Elisabet Lidbrink
# 39/208 --- Elzbieta Wojtyna-Dziedzic
# 40/208 --- Eva af Trampe
# 41/208 --- Ann-Britt Nilsson
# 42/208 --- Eva Tallroth
# 43/208 --- Evangelos Digkas
# 44/208 --- Fredrika Killander
# 45/208 --- Gabriel Jonsson
# 46/208 --- Gerhard Winblad
# 47/208 --- Gilberto Morgan
# 48/208 --- Git Martenhed
# 49/208 --- Greger Nilsson
# 50/208 --- Gunnar Lengstrand
# 51/208 --- Marika Hjelmqvist
# 52/208 --- Helena Granstam Björneklett
# 53/208 --- Anna Askelin
# 54/208 --- Henrik Lindman
# 55/208 --- Ida Spång Rosén
# 56/208 --- Jamila Adra
# 57/208 --- Jan Frisell
# 58/208 --- Jenny Bergqvist
# 59/208 --- Johan Ahlgren
# 60/208 --- Johan Hartman
# 61/208 --- Jonas Bergh
# 62/208 --- Jonas Holm
# 63/208 --- Jörn Schneede
# 64/208 --- Judith Bjöhle
# 65/208 --- Karolina Larsson
# 66/208 --- Katalin Marianna Kovacs
# 67/208 --- Anna Lind
# 68/208 --- Kenneth Villman
# 69/208 --- Carin Lundgren
# 70/208 --- Susanne Söder
# 71/208 --- Kilian Bachmeier
# 72/208 --- Kristina Engvall
# 73/208 --- Eva Ulff
# 74/208 --- Lars Norberg
# 75/208 --- Leif Klint
# 76/208 --- Lena Nittby Tennvall
# 77/208 --- Linda Thorén
# 78/208 --- Magnus Lagerlund
# 79/208 --- Malgorzata Drozd-Lula
# 80/208 --- Mari Åhs
# 81/208 --- Maria Ekholm
# 82/208 --- Gudrun Linderkers
# 83/208 --- Karin Maltenius
# 84/208 --- Maria Svensson
# 85/208 --- Marie Klintman
# 86/208 --- Marie Zajicova
# 87/208 --- Karin Jannesson
# 88/208 --- Kicki Klaeson
# 89/208 --- Martin Malmberg
# 90/208 --- Mats Andén
# 91/208 --- Mihalj Seke
# 92/208 --- Munila Mudaisi
# 93/208 --- Nils Wilking
# 94/208 --- Nils-Olof Bengtsson
# 95/208 --- Nina Letter Al-Ayoubi
# 96/208 --- Pär Bodén
# 97/208 --- Paulina Krywda
# 98/208 --- Pehr Lind
# 99/208 --- Per Byström
# 100/208 --- Per Edlund
# 101/208 --- Per Karlsson
# 102/208 --- Per Malmström
# 103/208 --- Kala Hatti Önnerfält
# 104/208 --- Anna-Karin Åkesson
# 105/208 --- Renske Altena
# 106/208 --- Reza Khoshnoud
# 107/208 --- Roger Henriksson
# 108/208 --- Sara Margolin
# 109/208 --- Sigrid Karstorp
# 110/208 --- Thomas Edekling
# 111/208 --- Thomas Hatschek
# 112/208 --- Tobias Lekberg
# 113/208 --- Tommy Fornander
# 114/208 --- Ulrik Narbe
# 115/208 --- Ulrika Palenius
# 116/208 --- Ylva Sandeder
# 117/208 --- Zakaria Einbeigi
# 118/208 --- Irma Fredriksson
# 119/208 --- Paul Holmer
# 120/208 --- Christine Lundgren
# 121/208 --- Sara Wirén
# 122/208 --- Emma Sjöström
# 123/208 --- Johan Falkenius
# 124/208 --- Alexios Matikas
# 125/208 --- Sandra Cedervall
# 126/208 --- Anneli Fahlen
# 127/208 --- Helene Almström
# 128/208 --- Hildur Helgadottir
# 129/208 --- Gustav Ullenhag
# 130/208 --- Ylva Naeser
# 131/208 --- Anthoula Koliadi
# 132/208 --- Karin Hallén
# 133/208 --- Sara Tärnbro
# 134/208 --- Charlotte Levin
# 135/208 --- Georgios Kitsolampros
# 136/208 --- Braslav Jovanovic
# 137/208 --- Fernanda Costa Svedman
# 138/208 --- Giuseppe Masucci
# 139/208 --- Lisa Elena Esther Villabona
# 140/208 --- Maria Wolodarski
# 141/208 --- Elin Jänes
# 142/208 --- Petra Flygare
# 143/208 --- Dimitrios Papantoniou
# 144/208 --- Ingrid Schampi Ljuslinder
# 145/208 --- Karin Papworth
# 146/208 --- Max Levin
# 147/208 --- Sara Bjursten
# 148/208 --- Kristin Sigurjonsdottir
# 149/208 --- Christine Jaredsson
# 150/208 --- Sander Ellegård
# 151/208 --- Jan Rzepecki
# 152/208 --- Georgios Fountoukidis
# 153/208 --- Elin Brodin
# 154/208 --- Michael Sihver
# 155/208 --- Zuzana Lovasová
# 156/208 --- Karin Engblom
# 157/208 --- Jenny Furubrand
# 158/208 --- Lena C Andersson
# 159/208 --- Karin Törnkvist
# 160/208 --- Sofia Wikström
# 161/208 --- Lena Westerberg
# 162/208 --- Eva Lindblad
# 163/208 --- Liselott Sahlberg
# 164/208 --- Per Nodbrant
# 165/208 --- Marie Johansson
# 166/208 --- Sofie Dietl
# 167/208 --- Elisabet Olsson Kivipaasi
# 168/208 --- Karin Nilsson
# 169/208 --- Marianne Pettersson
# 170/208 --- Marinette Berglund
# 171/208 --- Sara Margareta Ekenbro
# 172/208 --- Lena Samuelsson
# 173/208 --- Margareth Schoultz
# 174/208 --- Hervor Gramén
# 175/208 --- Mari Johansson
# 176/208 --- Karin Samuelsson
# 177/208 --- Lise-Lotte Jönsson
# 178/208 --- Malin Ståhl
# 179/208 --- Lena Berg
# 180/208 --- Camilla Persson
# 181/208 --- Marie Boberg
# 182/208 --- Pernilla Karlsson
# 183/208 --- Lotta Henriksson
# 184/208 --- Karin Johansson
# 185/208 --- Charlotta Pramsten
# 186/208 --- Lola Svensson
# 187/208 --- Daniel Giglio
# 188/208 --- Elsy-Britt Schildt
# 189/208 --- Erika Isaksson Friman
# 190/208 --- Eva Djureen Mårtenson
# 191/208 --- Lars Ny
# 192/208 --- Harriet Axelsson
# 193/208 --- Gustav Silander
# 194/208 --- Lisa Rydén
# 195/208 --- Carina Larsson
# 196/208 --- Karin Lycknert
# 197/208 --- Niklas Loman
# 198/208 --- Olga Del Val Munoz
# 199/208 --- Olof Bjarnadottir
# 200/208 --- Samuel Rotstein
# 201/208 --- Sara Kinhult
# 202/208 --- Theodoros Foukakis
# 203/208 --- Maria Gränström
# 204/208 --- Ylva Holmgren Stenlund
# 205/208 --- Anna Nyberg
# 206/208 --- Göran Carlstedt
# 207/208 --- Mikael Wallander
# 208/208 --- Frida Jakobsson
# saving file corresponding to results_queries_API.csv
# 0 hours 15.04 minutes

# %% [markdown]
# ## Results

# %%
results_queries_pm = pd.read_csv(f"{route0}/results_queries_pm.csv")
results_queries_pm
# Out:
#                  hcp_name  num_articles  \
# 0     Adel Bader Hamdalla             0
# 1           Aglaia Schiza             6
# 2           Aglaia Schiza             6
# 3           Aglaia Schiza             6
# 4           Aglaia Schiza             6
# ...                   ...           ...
# 4142      Göran Carlstedt             0
# 4143     Mikael Wallander             1
# 4144      Frida Jakobsson             3
# 4145      Frida Jakobsson             3
# 4146      Frida Jakobsson             3
#
#                                                abstract  \
# 0                                                   NaN
# 1     The immune microenvironment is an important mo...
# 2     Trastuzumab emtansine (T-DM1) is presently app...
# 3     This study analyzes the potential of stromal p...
# 4     There are conflicting results on the potential...
# ...                                                 ...
# 4142                                                NaN
# 4143  While recent randomised phase III trials show ...
# 4144  Treating localized prostate cancer (PC) with c...
# 4145  The benefit of imaging in the follow-up settin...
# 4146  The incidence of cutaneous malignant melanoma ...
#
#                                                 authors  \
# 0                                                   NaN
# 1     [('Aglaia', 'Schiza'), ('Viktoria', 'Thurfjell...
# 2     [('Thomas', 'Hatschek'), ('Theodoros', 'Foukak...
# 3     [('Carina', 'Strell'), ('Dick', 'Folkvaljon'),...
# 4     [('Aglaia', 'Schiza'), ('Davide', 'Mauri'), ('...
# ...                                                 ...
# 4142                                                NaN
# 4143  [('Mikael', 'Wallander'), ('Bo', 'Rolander'), ...
# 4144  [('Johan Staby', 'Olsén'), ('Dalia', 'Estefan'...
# 4145  [('Ylva', 'Naeser'), ('Hildur', 'Helgadottir')...
# 4146  [('Ylva', 'Naeser'), ('Hildur', 'Helgadottir')...
#
#                                             conclusions  \
# 0                                                   NaN
# 1     High TILs are associated with higher IBE risk ...
# 2                                                   NaN
# 3                                                   NaN
# 4     Our study results, based on propensity-matched...
# ...                                                 ...
# 4142                                                NaN
# 4143                                                NaN
# 4144                                                NaN
# 4145                                                NaN
# 4146                                                NaN
#
#                                              copyrights  \
# 0                                                   NaN
# 1     Copyright © 2022 The Author(s). Published by E...
# 2                                                   NaN
# 3       ©2021 American Association for Cancer Research.
# 4                                                   NaN
# ...                                                 ...
# 4142                                                NaN
# 4143  2020 Journal of Gastrointestinal Oncology. All...
# 4144                         Copyright © 2022 Termedia.
# 4145                                                NaN
# 4146                                                NaN
#
#                                                 journal  \
# 0                                                   NaN
# 1     European journal of cancer (Oxford, England : ...
# 2                                         JAMA oncology
# 3     Clinical cancer research : an official journal...
# 4                  Breast cancer research and treatment
# ...                                                 ...
# 4142                                                NaN
# 4143               Journal of gastrointestinal oncology
# 4144              Journal of contemporary brachytherapy
# 4145                                            Cancers
# 4146                                         BMC cancer
#
#                                                keywords methods  \
# 0                                                   NaN     NaN
# 1     ['Ductal carcinoma in situ', 'Radiotherapy', '...     NaN
# 2                                                    []     NaN
# 3                                                    []     NaN
# 4     ['Adjuvant', 'Breast cancer', 'Endocrine treat...     NaN
# ...                                                 ...     ...
# 4142                                                NaN     NaN
# 4143  ['Trifluridine and tiperacil (TAS-102)', 'chem...     NaN
# 4144  ['HDR', 'boost', 'brachytherapy', 'hypo-fracti...     NaN
# 4145  ['X-ray computed', 'follow-up studies', 'melan...     NaN
# 4146  ['CT', 'Cutaneous malignant melanoma', 'FDG-PE...     NaN
#
#      publication_date                                          pubmed_id  \
# 0                 NaN                                                NaN
# 1          2022-03-04                                           35236568
# 2          2021-06-25                                           34165503
# 3          2021-05-07                                           33952629
# 4          2020-12-02  33258078\n16000569\n26211827\n29242041\n279564...
# ...               ...                                                ...
# 4142              NaN                                                NaN
# 4143       2020-09-22  32953145\n27522626\n23438360\n31914811\n274124...
# 4144       2022-03-03  35233229\n15465142\n20141674\n27771243\n233183...
# 4145       2022-02-26  35205786\n9440735\n27183845\n8433390\n11832252...
# 4146       2020-12-09  33287744\n18844268\n16632217\n27183845\n218102...
#
#                                                 results  \
# 0                                                   NaN
# 1     Most women (61.9%) showed a TILs prevalence of...
# 2                                                   NaN
# 3     PDGFRb score was predictive for RT benefit wit...
# 4     After propensity score matching, 4368 patients...
# ...                                                 ...
# 4142                                                NaN
# 4143                                                NaN
# 4144                                                NaN
# 4145                                                NaN
# 4146  The first patient was recruited in June 2017 a...
#
#                                                   title
# 0                                                   NaN
# 1     Tumour-infiltrating lymphocytes add prognostic...
# 2     Neoadjuvant Trastuzumab, Pertuzumab, and Docet...
# 3     High PDGFRb Expression Predicts Resistance to ...
# 4     Predictive role of HER2-status on the effectiv...
# ...                                                 ...
# 4142                                                NaN
# 4143  Real world aspects of palliative trifluridine ...
# 4144  Predicting toxicity caused by high-dose-rate b...
# 4145  Quality of Life in the First Year of Follow-Up...
# 4146  TRIM study protocol - a prospective randomized...
#
# [4147 rows x 13 columns]
